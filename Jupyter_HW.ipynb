# %%
import requests
import json
from bs4 import BeautifulSoup
import pandas as pd
from fake_useragent import UserAgent

# %%
def job_content(url):
    headers = {
    "Accept": "application/json, text/plain, */*",
    "Accept-Encoding": "gzip, deflate, br",
    "Accept-Language": "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6",
    "Connection": "keep-alive",
    "Host": "www.104.com.tw",
    "Referer": f"https://www.104.com.tw/job/{a}?jobsource=hotjob_chr",
    "sec-ch-ua": '" Not A;Brand";v="99", "Chromium";v="96", "Google Chrome";v="96"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": "Windows",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin",
    "User-Agent": ua.random
    }
    
    res = requests.get(url, headers=headers)
    soup = BeautifulSoup(res.text, 'html.parser')
    temp = soup.select('link')[0]['href']

    res = rs.get(url, headers=headers)
    res.text

# %%
title = input()
url = f"https://www.104.com.tw/jobs/search/?keyword={title}&order=1&jobsource=2018indexpoc&ro=0"

ua = UserAgent()
user_agent = ua.random
headers = {
    'User-Agent' : user_agent
}

# userAgent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.81 Safari/537.36"
# headers = {
#     'User-Agent' : userAgent
# }

rs = requests.session()
res = rs.get(url, headers=headers)
soup = BeautifulSoup(res.text, 'html.parser')
soup


df = pd.DataFrame(columns=['data_cust_name', 'job_name'])
for i in range(0, len(soup.select('article'))):
    try:
        job_name = soup.select('article')[i]['data-job-name']
        data_cust_name = soup.select('article')[i]['data-cust-name']
                
        add_dataframe = pd.DataFrame({'data_cust_name':data_cust_name, 'job_name':job_name},index=[1])
        df = df.append(add_dataframe, ignore_index=True)
        
    except:
        pass
    
df
# job_name = soup.select('article')[10]['data-job-name']
# data_cust_name = soup.select('article')[10]['data-cust-name']
# Out:
# data
#                                        data_cust_name  \
# 0              Kloudless, A Netskope Company_科迪股份有限公司
# 1   台灣美光(台灣美光晶圓科技股份有限公司/台灣美光記憶體股份有限公司/美商美光亞太科技股份有限...
# 2   台灣美光(台灣美光晶圓科技股份有限公司/台灣美光記憶體股份有限公司/美商美光亞太科技股份有限...
# 3                                         沛思坦網路股份有限公司
# 4              台灣應用材料股份有限公司 _Applied Materials Taiwan
# 5                          美商科磊股份有限公司台灣分公司_KLA Taiwan
# 6                                        歐商_喜利得股份有限公司
# 7                                          偉太健康科技有限公司
# 8                                         奧圖碼科技股份有限公司
# 9                                        德誼數位科技股份有限公司
# 10                                           探宇資訊有限公司
# 11                               日商優必達株式會社股份有限公司台灣分公司
# 12                        Shopline Limited_商線科技股份有限公司
# 13                                       安布思沛行銷股份有限公司
# 14                                         巨量移動科技有限公司
# 15                               GoFreight_聖學科技股份有限公司
# 16                                         現觀科技股份有限公司
# 17                                           雲策數據有限公司
# 18                                  美商柏恩亞太股份有限公司台灣分公司
# 19                          Pinkoi_香港商果翼科技股份有限公司台灣分公司
# 20                                       沛星互動科技股份有限公司
# 21                                         台灣萊雅股份有限公司
# 22                                  美商柏恩亞太股份有限公司台灣分公司
# 23                                         台灣杜邦股份有限公司
# 24                                Ampd Energy Limited
# 25                        Shopline Limited_商線科技股份有限公司
# 26                                         現觀科技股份有限公司
# 27                                 IBM_台灣國際商業機器股份有限公司
# 28                                         順立智慧股份有限公司
# 29                          hyve solutions_海峰電腦股份有限公司
#
#                                              job_name
# 0                   Sr. Manager, Datapath Engineering
# 1      ENGINEER, PACKAGE ASSEMBLY PROCESS INTEGRATION
# 2             SR. ENGINEER, MATERIAL CHARACTERIZATION
# 3                   [Taipei]Legal Evidence Consultant
# 4   Information Security Analyst  資深資安管理師- Locatio...
# 5                 客服工程師(台南) Customer Service Engineer
# 6              Inside Sales Account Manager 客戶經理-電話銷售
# 7   新竹區專櫃銷售顧問（竹北遠百新開幕）Water Filters Sales Represen...
# 8                 資深全端工程師 Senior Full-Stack Developer
# 9                             《高雄市-視訊面試》APPLE專賣店-銷售專員
# 10                                      Data Engineer
# 11                                      Data Engineer
# 12                                      Data Engineer
# 13                                      Data Engineer
# 14                                     Data Scientist
# 15                                   CRM Data Analyst
# 16           Data Engineer (Data Management Platform)
# 17                                Senior Data Analyst
# 18                       Sales Data Analytics Manager
# 19                         Data Scientist - Marketing
# 20                             Inventory Data Analyst
# 21                                  Data and CRM Lead
# 22                                 Sales Data Analyst
# 23                            Data Analyst/ Scientist
# 24                                      Data Engineer
# 25                               Data Product Manager
# 26                               【COVMO】Data Engineer
# 27                                  Big Data Engineer
# 28                               Data Engineer_Intern
# 29                             Software Data Engineer

# %%
from collections import Iterable
isinstance(soup.select('article'), Iterable)
# Out:
# C:\Users\TIBEME~1\AppData\Local\Temp/ipykernel_19348/1584499393.py:1: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3, and in 3.10 it will stop working
#   from collections import Iterable
# True

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="zh-hant"><head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>「data」找工作職缺－2021年12月｜104人力銀行</title>
# <meta content="2021年12月5日－5779 個工作機會｜Data Engineer【探宇資訊有限公司】、Data Engineer【日商優必達株式會社股份有限公司台灣分公司】、Data Engineer【Shopline Limited_商線科技股份有限公司】、Data Engineer【安布思沛行銷股份有限公司】、Data Scientist【巨量移動科技有限公司】、CRM Data Analyst【GoFreight_聖學科技股份有限公司】、Data Engineer (Data Management Platform)【現觀科技股份有限公司】、Senior Data Analyst【雲策數據有限公司】、Sales Data Analytics Manager【美商柏恩亞太股份有限公司台灣分公司】、Data Scientist - Marketing【Pinkoi_香港商果翼科技股份有限公司台灣分公司】。104人力銀行提供全台最多工作職缺，及專業求職服務，更多「data」找工作職缺請上104人力銀行搜尋。" name="description"/>
# <meta content="「data」找工作職缺－2021年12月｜104人力銀行" property="og:title"/>
# <meta content="https://cdn.104.com.tw/static/images/og/company.png" property="og:image"/>
# <meta content="找頭鹿找公司｜ 104 人力銀行" property="“og:image:alt”">
# <meta content="https://www.104.com.tw/jobs/search/?keyword=data&amp;langFlag=0&amp;remoteWork=" property="og:url"/>
# <meta content="website" property="og:type"/>
# <meta content="104人力銀行" property="og:site_name"/>
# <meta content="2021年12月5日－5779 個工作機會｜Data Engineer【探宇資訊有限公司】、Data Engineer【日商優必達株式會社股份有限公司台灣分公司】、Data Engineer【Shopline Limited_商線科技股份有限公司】、Data Engineer【安布思沛行銷股份有限公司】、Data Scientist【巨量移動科技有限公司】、CRM Data Analyst【GoFreight_聖學科技股份有限公司】、Data Engineer (Data Management Platform)【現觀科技股份有限公司】、Senior Data Analyst【雲策數據有限公司】、Sales Data Analytics Manager【美商柏恩亞太股份有限公司台灣分公司】、Data Scientist - Marketing【Pinkoi_香港商果翼科技股份有限公司台灣分公司】。104人力銀行提供全台最多工作職缺，及專業求職服務，更多「data」找工作職缺請上104人力銀行搜尋。" property="og:description"/>
# <meta content="516245975144411" property="fb:app_id"/>
# <meta content="index,follow,noarchive" name="robots"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="//www.104.com.tw/jobs/search/?keyword=data&amp;langFlag=0&amp;remoteWork=" rel="canonical"/> <link href="//www.104.com.tw/jobs/search/?ro=0&amp;kwop=7&amp;keyword=data&amp;expansionType=area%2Cspec%2Ccom%2Cjob%2Cwf%2Cwktm&amp;order=12&amp;asc=0&amp;mode=s&amp;langFlag=0&amp;remoteWork=&amp;page=2" rel="next"/>
# <link href="//m.104.com.tw/search/joblist/?ro=0&amp;kwop=7&amp;keyword=data&amp;expansionType=area%2Cspec%2Ccom%2Cjob%2Cwf%2Cwktm&amp;order=12&amp;asc=0&amp;mode=s&amp;langFlag=0&amp;remoteWork=" media="only screen and (max-width: 640px)" rel="alternate"/> <link href="//static.104.com.tw/104main/jb/fonts/MsJhengHeiBold/icon.css?v=210217" rel="stylesheet"/>
# <link href="//static.104.com.tw/104main/jb/css/common.css?v=210217" rel="stylesheet" type="text/css"/>
# <link href="//www.104.com.tw/jobs/search/static/css/vendor.css?v=210217" rel="stylesheet" type="text/css"/>
# <link href="//www.104.com.tw/jobs/search/static/css/main.min.css?v=210217" rel="stylesheet" type="text/css"/>
# <link href="//www.104.com.tw/jobs/search/static/css/pages.min.css?v=210217" rel="stylesheet" type="text/css"/>
# <link href="//static.104.com.tw/104main/pda/css/category_org.css?v=210217" rel="stylesheet" type="text/css"/>
# <link href="//cdn.104.com.tw/designer-icons/1.1.12/style.css" rel="stylesheet" type="text/css"/> <script type="text/javascript">
#       var _elog = _elog||[];
#       try{
#         if(!document.getElementById('logjsapi') && !window.LOGAPIEXIST){
#           window.LOGAPIEXIST = true;
#           var SRV_104i_STATIC_ROOT = window.SRV_104i_STATIC_ROOT||'//static.104.com.tw/104i';
#           var elog = document.createElement('script');
#           elog.type = 'text/javascript';
#           elog.id = "logjsapi";
#           elog.async = true;
#           elog.src = SRV_104i_STATIC_ROOT +'/js/api/log/e104.log.latest.js?v=20140327';
#           var statusQueue = [];
#           elog.onreadystatechange = function() {
#             statusQueue.push(this.readyState);
#             if (this.readyState === 'loaded' && !Array.prototype.indexOf){
#               var testString = new RegExp('interactive');
#               if(!testString.test(statusQueue.join(','))){
#                 if(_elog[0] && _elog[0].callback && typeof _elog[0].callback === 'function'){_elog[0].callback.call(this);}
#               }
#             }
#           }
#           elog.onerror=function(){if(_elog[0] && _elog[0].callback && typeof _elog[0].callback === 'function'){_elog[0].callback.call(this);}};
#           var s = document.getElementsByTagName('script')[0];
#           s.parentNode.insertBefore(elog, s);
#         }
#       }catch(e){}
#     </script> <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-P379T3');</script> <script type="text/javascript">
#     _atrk_opts = { atrk_acct:"lRlHh1awVK00wf", domain:"104.com.tw",dynamic: true};
#     (function() { var as = document.createElement('script'); as.type = 'text/javascript'; as.async = true; as.src = "https://certify-js.alexametrics.com/atrk.js"; var s = document.getElementsByTagName('script')[0];s.parentNode.insertBefore(as, s); })();
#     </script>
# <noscript><img alt="" height="1" src="https://certify.alexametrics.com/atrk.gif?account=lRlHh1awVK00wf" style="display:none" width="1"/></noscript> <script async="" src="//www.104.com.tw/public/function01/utf8/jsonArea.js?v=210217"></script>
# <script async="" src="//www.104.com.tw/public/function01/utf8/jsonJobCat.js?v=210217"></script>
# <script async="" src="//www.104.com.tw/public/function01/utf8/jsonJobCatH.js?v=210217"></script>
# <script async="" src="//www.104.com.tw/public/function01/utf8/jsonIndust.js?v=210217"></script>
# <script async="" src="//www.104.com.tw/public/function01/utf8/jsonMajor.js?v=210217"></script>
# <script async="" src="//www.104.com.tw/public/function01/utf8/jsonAreaWork.js?v=210217"></script>
# <!-- category picker -->
# <link href="https://cdn.104.com.tw/category-tool/css/category-picker-2.0.0.css" rel="stylesheet" type="text/css"/>
# <script async="" src="https://cdn.104.com.tw/category-tool/js/category-picker-2.0.0.js" type="text/javascript"></script>
# <!-- Prefetch 捷運站 JSON Data -->
# <link href="https://static.104.com.tw/category-tool/json/Mrt.json" rel="prefetch"/>
# </meta></head>
# <body class="job-list-body" id="job-jobList"><noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-P379T3" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript><script type="application/ld+json">[
#     {
#         "@context": "https:\/\/schema.org",
#         "@type": "BreadcrumbList",
#         "itemListElement": [
#             {
#                 "@type": "ListItem",
#                 "position": 1,
#                 "name": "104 人力銀行",
#                 "item": "https:\/\/www.104.com.tw"
#             },
#             {
#                 "@type": "ListItem",
#                 "position": 2,
#                 "name": "找工作",
#                 "item": "https:\/\/www.104.com.tw\/jobs\/search"
#             },
#             {
#                 "@type": "ListItem",
#                 "position": 3,
#                 "name": "「data」找工作職缺",
#                 "item": "https:\/\/www.104.com.tw\/jobs\/search\/?keyword=data&langFlag=0&remoteWork="
#             }
#         ]
#     },
#     {
#         "@context": "https:\/\/schema.org",
#         "@type": "WebSite",
#         "url": "\/\/www.104.com.tw",
#         "name": "104 人力銀行",
#         "potentialAction": {
#             "@type": "SearchAction",
#             "target": "https:\/\/www.104.com.tw\/jobs\/search\/?keyword={searchTerms}&jobsource=open",
#             "query-input": "required name=searchTerms"
#         }
#     },
#     {
#         "@context": "https:\/\/schema.org",
#         "@type": "Event",
#         "startDate": "2021\/12\/05",
#         "eventAttendanceMode": "https:\/\/schema.org\/MixedEventAttendanceMode",
#         "eventStatus": "EventScheduled",
#         "name": "Data Engineer",
#         "organizer": {
#             "@type": "Organization",
#             "name": "探宇資訊有限公司",
#             "url": "https:\/\/www.104.com.tw\/company\/1a2x6bl8gf"
#         },
#         "location": {
#             "@type": "Place",
#             "name": "台北市信義區",
#             "address": {
#                 "@type": "PostalAddress",
#                 "postalCode": 110
#             }
#         },
#         "performer": {
#             "@type": "Organization",
#             "url": "https:\/\/www.104.com.tw\/company\/1a2x6bl8gf",
#             "name": "探宇資訊有限公司"
#         },
#         "description": "Responsibilities\r\n- Mine and analyze [[[data]]] from company databases to drive optimization and improvement of current business",
#         "image": "https:\/\/static.104.com.tw\/b_profile\/cust_picture\/1823\/130000000151823\/logo.png?v=20211007122514",
#         "url": "https:\/\/www.104.com.tw\/job\/6z6xb",
#         "offers": {
#             "@type": "Offer",
#             "url": "https:\/\/www.104.com.tw\/company\/1a2x6bl8gf",
#             "priceCurrency": "TWD",
#             "description": "免費",
#             "price": "0",
#             "availability": "http:\/\/schema.org\/InStock",
#             "validFrom": "2021\/12\/05"
#         }
#     },
#     {
#         "@context": "https:\/\/schema.org",
#         "@type": "Event",
#         "startDate": "2021\/12\/05",
#         "eventAttendanceMode": "https:\/\/schema.org\/MixedEventAttendanceMode",
#         "eventStatus": "EventScheduled",
#         "name": "Data Engineer",
#         "organizer": {
#             "@type": "Organization",
#             "name": "日商優必達株式會社股份有限公司台灣分公司",
#             "url": "https:\/\/www.104.com.tw\/company\/1a2x6bkqg3"
#         },
#         "location": {
#             "@type": "Place",
#             "name": "台北市松山區",
#             "address": {
#                 "@type": "PostalAddress",
#                 "postalCode": 105
#             }
#         },
#         "performer": {
#             "@type": "Organization",
#             "url": "https:\/\/www.104.com.tw\/company\/1a2x6bkqg3",
#             "name": "日商優必達株式會社股份有限公司台灣分公司"
#         },
#         "description": "DESCRIPTION\n\nUbitus is seeking an enthusiastic and aspiring big [[[data]]] engineer with “can-do” and “eager-to-learn” attitude",
#         "image": "https:\/\/static.104.com.tw\/b_profile\/cust_picture\/8483\/130000000128483\/logo.png?v=20211124171941",
#         "url": "https:\/\/www.104.com.tw\/job\/77uu6",
#         "offers": {
#             "@type": "Offer",
#             "url": "https:\/\/www.104.com.tw\/company\/1a2x6bkqg3",
#             "priceCurrency": "TWD",
#             "description": "免費",
#             "price": "0",
#             "availability": "http:\/\/schema.org\/InStock",
#             "validFrom": "2021\/12\/05"
#         }
#     },
#     {
#         "@context": "https:\/\/schema.org",
#         "@type": "Event",
#         "startDate": "2021\/12\/05",
#         "eventAttendanceMode": "https:\/\/schema.org\/MixedEventAttendanceMode",
#         "eventStatus": "EventScheduled",
#         "name": "Data Engineer",
#         "organizer": {
#             "@type": "Organization",
#             "name": "Shopline Limited_商線科技股份有限公司",
#             "url": "https:\/\/www.104.com.tw\/company\/1a2x6bj96b"
#         },
#         "location": {
#             "@type": "Place",
#             "name": "台北市松山區",
#             "address": {
#                 "@type": "PostalAddress",
#                 "postalCode": 105
#             }
#         },
#         "performer": {
#             "@type": "Organization",
#             "url": "https:\/\/www.104.com.tw\/company\/1a2x6bj96b",
#             "name": "Shopline Limited_商線科技股份有限公司"
#         },
#         "description": " involve using [[[data]]]-mining and machine learning. with the vast amount of [[[data]]] that we currently have and growing",
#         "image": "https:\/\/static.104.com.tw\/b_profile\/cust_picture\/9443\/130000000059443\/custintroduce\/image1.jpg?v=20211108145509",
#         "url": "https:\/\/www.104.com.tw\/job\/7ccou",
#         "offers": {
#             "@type": "Offer",
#             "url": "https:\/\/www.104.com.tw\/company\/1a2x6bj96b",
#             "priceCurrency": "TWD",
#             "description": "免費",
#             "price": "0",
#             "availability": "http:\/\/schema.org\/InStock",
#             "validFrom": "2021\/12\/05"
#         }
#     }
# ]</script><header class="l-header header">
# <div id="globalbar">
# <div id="bar_m104">
# <div id="global_bk"></div>
# </div>
# </div>
# <div class="l-container">
# <div class="b-logo b-float-left">
# <a href="//www.104.com.tw">
# <img alt="104人力銀行" src="//static.104.com.tw/logo/104logo_o_180x26.svg"/>
# </a>
# </div>
# <div class="b-banner--dimond b-float-right">
# <div board="top-banner"></div>
# </div>
# </div>
# </header><main> <div class="tool-area b-fixed-right"> <ul class="side-tools poc-tools">
# <li class="intro" id="intro">
# <a href="javascript:void(0)">
# <svg class="icon-intro b-icon--weak-gray b-icon--w24">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-intro"></use>
# </svg>
# <span>新版介紹</span>
# </a>
# </li>
# </ul> <ul class="side-tools">
# <li class="gtm-fixed-save">
# <a href="//pda.104.com.tw/work/jobStore" target="blank">
# <svg class="icon-star b-icon--weak-gray b-icon--w24">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-star"></use>
# </svg>
# <span>儲存清單</span>
# </a>
# </li>
# <li class="go-top gtm-fixed-gotop" id="go-top">
# <a class="b-icon b-hide" href="#">
# <svg class="icon-go-top b-icon--weak-gray b-icon--w24">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-go-top"></use>
# </svg>
# <span>回到頂部</span>
# </a>
# </li>
# </ul>
# </div> <div class="search-wrapper" id="search-wrapper"> <div class="main-search">
# <form autocomplete="off" class="l-container main-search__form" id="js-search-form">
# <div class="b-fake-input"> <div class="b-search-block--l">
# <input data-temp="" id="keyword" maxlength="50" placeholder="關鍵字(例：職稱、公司名、技能專長...)" type="text"/>
# <svg class="icon-clear b-icon--weak-gray b-icon--w16" xmlns="http://www.w3.org/2000/svg">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-clear">
# </use>
# </svg>
# </div> <span class="b-divide"></span> <div class="b-search-block--m">
# <input data-temp="" id="area-cat" placeholder="地區" readonly="" type="text"/>
# <svg class="b-icon--weak-gray b-icon--w16">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-arrow-down">
# </use>
# </svg>
# </div> <span class="b-divide"></span> <div class="b-search-block--m">
# <input data-temp="" id="job-cat" placeholder="職務類別" readonly="" type="text"/>
# <svg class="b-icon--weak-gray b-icon--w16">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-arrow-down">
# </use>
# </svg>
# </div>
# </div>
# <button class="b-btn b-btn--primary is-large gtm-main-search" type="submit">
#                     搜尋
#                 </button>
# <div class="main-search__auxiliary" id="search-relative">
# <label>
# <input class="b-checkbox" id="only-title" type="checkbox"/>
#                         只搜尋職務名稱
#                     </label> <p class="js-related-keyword js-related-keyword--correction">
#                             你是不是要查：
#                             <span>
# <a class="b-link--gray" href="//www.104.com.tw/jobs/search/?ro=0&amp;kwop=7&amp;expansionType=area%2Cspec%2Ccom%2Cjob%2Cwf%2Cwktm&amp;order=12&amp;asc=0&amp;mode=s&amp;langFlag=0&amp;remoteWork=&amp;keyword=Tata&amp;jobsource=n104bank1">Tata
#                                 </a>
# </span>
# </p> <label>
# <input class="b-checkbox gtm-highend-switch" id="job-type" type="checkbox"/>切換高階職類
#                     </label>
# </div>
# </form>
# </div>
# <div class="tabbar">
# <div class="l-container">
# <div class="tabbar__tab active" data-gtm-tab="切換到職務頁籤" id="js-tabbar-tab-joblist">
#                     職務
#                 </div>
# <div class="tabbar__tab" data-gtm-tab="切換到公司頁籤" id="js-tabbar-tab-company">
#                     公司
#                 </div>
# </div>
# </div> <div class="filter-search is-shadow" id="filter-search"> <div class="l-container"> <ul class="js-filter-tab b-tabs" id="js-filter-tab"> <li class="b-tabs__item js-arrow-toggle js-tab-content" data-value="0">
# <span class="b-tabs__txt js-tab-title" data-title="更新日期">
#                             更新日期
#                         </span>
# <svg class="b-icon--weak-gray b-icon--w16">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-arrow-down">
# </use>
# </svg>
# </li> <li class="b-tabs__item js-arrow-toggle js-tab-content" data-value="1">
# <span class="b-tabs__txt js-tab-title" data-title="出勤制度">
#                             出勤制度
#                         </span>
# <svg class="b-icon--weak-gray b-icon--w16">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-arrow-down">
# </use>
# </svg>
# </li> <li class="b-tabs__item js-arrow-toggle js-tab-content" data-value="2"> <span class="b-tabs__txt js-tab-title" data-title="薪資待遇">
#                                 薪資待遇
#                             </span> <svg class="b-icon--weak-gray b-icon--w16">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-arrow-down">
# </use>
# </svg>
# </li> <li class="b-tabs__item js-arrow-toggle js-tab-content" data-value="3"> <span class="b-tabs__txt js-tab-title" data-title="經歷要求">
#                                 經歷要求
#                             </span> <svg class="b-icon--weak-gray b-icon--w16">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-arrow-down">
# </use>
# </svg>
# </li> <li class="b-tabs__item js-arrow-toggle js-tab-content" data-value="4">
# <span class="b-tabs__txt js-tab-title" data-title="公司相關">
#                             公司相關
#                         </span>
# <svg class="b-icon--weak-gray b-icon--w16">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-arrow-down">
# </use>
# </svg>
# </li> <li class="b-tabs__item js-arrow-toggle js-tab-content" data-value="5">
# <span class="b-tabs__txt js-tab-title" data-title="更多條件">
#                             更多條件
#                         </span>
# <svg class="b-icon--weak-gray b-icon--w16">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-arrow-down">
# </use>
# </svg>
# </li> <li class="b-tabs__item js-arrow-toggle js-tab-content" data-value="6">
# <span class="b-tabs__txt js-tab-title" data-title="排除條件">
#                             排除條件
#                         </span>
# <svg class="b-icon--weak-gray b-icon--w16">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-arrow-down">
# </use>
# </svg>
# </li> </ul> <ul class="b-tabs__right-side">
# <li class="b-tabs__item gtm-sub-clear" id="js-filter-clear">
# <svg class="b-icon--w16">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-empty">
# </use>
# </svg>
# <span class="text-label" data-title="清空條件">
#                             清空條件
#                         </span>
# </li>
# <div class="b-divide"></div>
# <li class="b-tabs__item job-match-btn gtm-sub-subscription" data-popup="saveCondition" id="search-conditon" title="檢視或訂閱條件">
# <svg class="b-icon--w16">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-ring">
# </use>
# </svg>
# <span class="text-label">檢視或訂閱條件</span>
# </li>
# </ul> <div>
# <img alt="104人力銀行 - 新版介紹" class="intro-step1 intro-layer" src="//www.104.com.tw/jobs/search/static/img/intro/intro-1.jpg" srcset="//www.104.com.tw/jobs/search/static/img/intro/intro-1@2x.jpg 2x,//www.104.com.tw/jobs/search/static/img/intro/intro-1@3x.jpg 3x"/>
# <img alt="104人力銀行 - 新版介紹" class="intro-step2 intro-layer" src="//www.104.com.tw/jobs/search/static/img/intro/intro-2.jpg" srcset="//www.104.com.tw/jobs/search/static/img/intro/intro-2@2x.jpg 2x,//www.104.com.tw/jobs/search/static/img/intro/intro-2@3x.jpg 3x"/>
# <img alt="104人力銀行 - 新版介紹" class="intro-step3 intro-layer" src="//www.104.com.tw/jobs/search/static/img/intro/intro-3.jpg" srcset="//www.104.com.tw/jobs/search/static/img/intro/intro-3@2x.jpg 2x,//www.104.com.tw/jobs/search/static/img/intro/intro-3@3x.jpg 3x"/>
# </div>
# </div> <div class="l-content b-tabs-content has-background is-shadow b-hide js-sub-filter" id="js-sub-filter">
# <div class="l-container sub-search"> <div class="js-filter-tab-content js-filter-select-list b-hide" data-filter-type="updateTime" data-select-type="1"></div> <div class="js-filter-tab-content b-hide">
# <dl class="labels-field js-middle-select-list">
# <dt>
# <span class="title">上班時段</span>
# </dt>
# <dd>
# <span class="js-filter-select-list" data-filter-type="workingHours" data-select-type="2"></span>
# <span class="b-divide"></span>
# <span class="js-filter-select-list" data-filter-type="shiftwork" data-select-type="1"></span>
# </dd>
# </dl>
# <dl class="labels-field js-middle-select-list">
# <dt>
# <span class="title">休假制度</span>
# </dt>
# <dd>
# <span class="js-filter-select-list" data-filter-type="workingDays" data-select-type="1"></span>
# </dd>
# </dl>
# <dl class="labels-field js-middle-select-list">
# <dt>
# <span class="title">上班型態</span>
# </dt>
# <dd>
# <span class="js-filter-select-list" data-filter-type="remoteWork" data-select-type="2"></span>
# </dd>
# </dl>
# </div> <div class="js-filter-tab-content b-hide" data-select-type="1" id="js-salary"> <dl class="labels-field">
# <dt>
# <span class="title">薪資條件</span>
# </dt>
# <dd>
# <span class="js-salary-list">
# <label>
# <input type="checkbox" value="99"/>
# <span>有寫薪資</span>
# <svg class="icon-clear b-icon--w16">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-clear"></use>
# </svg>
# </label>
# <label>
# <input type="checkbox" value="30000"/>
# <span>月薪3萬up</span>
# <svg class="icon-clear b-icon--w16">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-clear"></use>
# </svg>
# </label>
# <label>
# <input type="checkbox" value="40000"/>
# <span>月薪4萬up</span>
# <svg class="icon-clear b-icon--w16">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-clear"></use>
# </svg>
# </label>
# <label>
# <input type="checkbox" value="50000"/>
# <span>月薪5萬up</span>
# <svg class="icon-clear b-icon--w16">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-clear"></use>
# </svg>
# </label>
# </span>
# </dd>
# </dl> <dl class="labels-field select-field" id="js-salary-custom">
# <dt>
# <span class="title">自訂條件</span>
# </dt>
# <dd>
# <span class="labels">
# <label class="js-salary-range b-hide">
# <input type="checkbox"/>
# <span></span>
# <svg class="icon-clear b-icon--w16">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-clear"></use>
# </svg>
# </label>
# </span>
# <div class="salary-custom js-salary-custom select-category"> <div class="salary-input js-salary-input">
# <div class="input-group">
# <select class="b-clear-border cus-select js-salary-type">
# <option value="H">時薪</option>
# <option value="D">日薪</option>
# <option selected="selected" value="M">月薪</option>
# <option value="Y">年薪</option>
# </select>
# <div class="b-divide"></div>
# <input autocomplete="off" class="salary-min b-clear-border js-salary-min" maxlength="7" placeholder="如28000" type="number"/>
# </div>
# <span class="b-dash"></span>
# <input autocomplete="off" class="js-salary-max salary-max" maxlength="7" placeholder="可不填" type="number"/>
# <button class="b-btn b-btn--default js-salary-send" disabled="">
#                                             送出
#                                         </button>
# </div>
# </div>
# </dd>
# </dl> <dl class="labels-field" id="salary-result">
# <dt>
# <span class="title">查詢結果</span>
# </dt>
# <dd class="salary-result-all">
# <span>
# <label class="freeze">
# <input checked="" class="b-checkbox" type="checkbox" value="1"/>
# <span>所有工作</span>
# </label>
# </span>
# </dd> <dd class="js-filter-select-checkbox-list" data-filter-type="salaryNeg" data-select-type="1"></dd>
# </dl>
# </div> <div class="js-filter-tab-content js-filter-select-list b-hide" data-filter-type="experience" data-select-type="2"></div> <div class="js-filter-tab-content b-hide">
# <dl class="labels-field select-field js-middle-select-list">
# <dt>
# <span class="title">公司產業</span>
# </dt>
# <dd>
# <span class="labels js-filter-select-category" data-category-desc="選擇其他產業" data-filter-type="industry"></span>
# </dd>
# </dl>
# <dl class="labels-field js-middle-select-list">
# <dt>
# <span class="title">科技園區</span>
# </dt>
# <dd class="js-filter-select-list" data-filter-type="techArea" data-select-type="1"></dd>
# </dl>
# <dl class="labels-field select-field js-middle-select-list">
# <dt>
# <span class="title">工業區</span>
# </dt>
# <dd>
# <span class="labels js-filter-select-category" data-category-desc="請選擇工業區" data-filter-type="areaWork"></span>
# </dd>
# </dl>
# <dl class="labels-field js-middle-select-list">
# <dt>
# <span class="title">福利制度</span>
# </dt>
# <dd class="js-filter-select-list" data-filter-type="welfare" data-select-type="2"></dd>
# </dl>
# <dl class="labels-field js-middle-select-list">
# <dt>
# <span class="title">公司類型</span>
# </dt>
# <dd class="js-filter-select-list" data-filter-type="custType" data-select-type="1"></dd>
# </dl>
# </div> <div class="js-filter-tab-content b-hide">
# <dl class="labels-field js-middle-select-list">
# <dt>
# <span class="title">工讀性質</span>
# </dt>
# <dd class="js-filter-select-list" data-filter-type="partTime" data-select-type="2"></dd>
# </dl>
# <dl class="labels-field js-middle-select-list">
# <dt>
# <span class="title">學歷要求</span>
# </dt>
# <dd class="js-filter-select-list" data-filter-type="education" data-select-type="2"></dd>
# </dl>
# <dl class="labels-field js-middle-select-list">
# <dt>
# <span class="title">外語要求</span>
# </dt>
# <dd class="js-filter-select-list" data-filter-type="language" data-select-type="2"></dd>
# </dl>
# <dl class="labels-field select-field js-middle-select-list">
# <dt>
# <span class="title">科系要求</span>
# </dt>
# <dd>
# <span class="labels js-filter-select-category" data-category-desc="選擇科系" data-filter-type="major" id="js-major"></span>
# </dd>
# </dl>
# <dl class="labels-field dl-for-rostatus js-middle-select-list">
# <dt>
# <span class="title">身份類型</span>
# </dt>
# <dd class="js-filter-select-list" data-filter-type="roleStatus" data-select-type="2"></dd>
# </dl>
# <dl class="labels-field select-field" id="js-disrole-custom">
# <dt>
# <span class="title">接受身障</span>
# </dt>
# <dd>
# <div class="salary-custom js-disrole-custom select-category">
# <div class="salary-input js-disrole-input">
# <div class="input-group">
# <select class="b-clear-border cus-select js-disrole-type">
# <option value="">選擇身障類型</option>
# <option value="99">不拘</option>
# <option value="1">視覺障礙</option>
# <option value="2">聽覺或平衡機能障礙</option>
# <option value="3">自閉症</option>
# <option value="4">慢性精神病</option>
# <option value="5">肢體障礙(上肢)</option>
# <option value="6">肢體障礙(下肢)</option>
# <option value="7">肢體障礙(軀幹)</option>
# <option value="8">聲音或語言機能障礙</option>
# <option value="9">顏面損傷</option>
# <option value="10">其他障礙</option>
# </select>
# </div>
# </div>
# </div>
# </dd>
# </dl>
# </div> <div class="js-filter-tab-content b-hide">
# <dl class="labels-field js-middle-select-list">
# <dt>
# <span class="title">排除派遣</span>
# </dt>
# <dd class="js-filter-select-list" data-filter-type="excludeTemp" data-select-type="1"></dd>
# </dl>
# <dl class="labels-field select-field">
# <dt>
# <span class="title">排除產業</span>
# </dt>
# <dd>
# <span class="labels js-middle-select-list" id="js-exclude-industry"></span>
# </dd>
# </dl>
# <dl class="labels-field select-field">
# <dt>
# <span class="title">排除關鍵字</span>
# </dt>
# <dd id="js-exclude-job">
# <span class="labels js-middle-select-list" id="js-exclude-job-field"></span>
# <div class="text-input">
# <input maxlength="30" placeholder="請輸入欲排除的關鍵字" type="text"/>
# <button class="b-btn b-btn--default" disabled="">送出</button>
# </div>
# </dd>
# </dl>
# <dl class="labels-field select-field">
# <dt>
# <span class="title">排除公司</span>
# </dt>
# <dd id="js-exclude-company">
# <span class="labels js-middle-select-list" id="js-exclude-company-field"></span>
# <div class="text-input">
# <input placeholder="請輸入公司名稱" type="text"/>
# <button class="b-btn b-btn--default" disabled="">送出</button>
# </div>
# </dd>
# </dl>
# </div> <div class="js-filter-tab-content b-hide">
# <dl class="labels-field js-middle-select-list">
# <dt>
# <span class="title">捷運附近</span>
# </dt>
# <dd>
# <span class="labels js-filter-select-category js-filter-new-select-category" data-category-desc="請選擇捷運站" data-filter-type="mrt" id="js-mrt"></span>
# </dd>
# </dl>
# </div>
# </div>
# </div>
# </div>
# </div> <div class="l-content--2col b-clearfix" id="main-content">
# <div class="l-content--2col--main l-container jobs-content"> <div class="js-related-companies related-companies--top">
# <span>找公司：</span>
# <a class="others-company js-custName" href="//www.104.com.tw/company/5wp49rs?jobsource=joblist_r_cust" target="_blank">威剛科技股份有限公司</a>
# <ul class="js-related-list"></ul>
# </div> <div class="job-tab b-clearfix" id="js-job-header">
# <div class="b-float-right">
# <label class="b-select">
# <select class="page-select js-paging-select gtm-paging-top"></select>
# </label>
# <label class="b-select">
# <select id="js-sort">
# <option selected="" value="1-0">符合度排序</option>
# <option value="2-0">日期排序</option>
# <option value="4-0">學歷 高→低</option>
# <option value="4-1">學歷 低→高</option>
# <option value="3-0">經歷 多→少</option>
# <option value="3-1">經歷 少→多</option>
# <option value="7-0">應徵人數 多→少</option>
# <option value="7-1">應徵人數 少→多</option>
# <option value="13-0">待遇 高→低</option>
# <option value="13-1">待遇 低→高</option>
# </select>
# </label>
# <ul class="job-switch-mode">
# <li class="js-mode-summary">
# <a href="javascript:;" title="摘要">
# <svg class="b-icon--w18 b-pointer-events">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-mode-s" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </a>
# </li>
# <li class="js-mode-list">
# <a href="javascript:;" title="列表">
# <svg class="b-icon--w18 b-pointer-events">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-mode-l" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </a>
# </li>
# </ul>
# </div>
# <div class="b-float-left">
# <ul class="b-nav-tabs job-type" id="js-job-tab">
# <li data-value="0">全部<span class="js-txt"></span></li>
# <li data-value="1">全職<span class="js-txt"></span></li>
# <li data-value="2">兼職<span class="js-txt"></span></li>
# <li data-value="3">高階<span class="js-txt"></span></li>
# <li class="b-drowdown" data-value="4">
# <button class="b-btn b-btn--dropdown" id="js-job-more">其他</button>
# <ul class="b-drowdown__menu b-hide">
# <li data-value="4">派遣<span class="js-txt"></span></li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="b-block b-clear-border b-clearfix job-list" id="js-job-list">
# <div class="b-block--top-bord job-list-item b-block--load b-clearfix js-loading-refresh b-hide">
# <div class="b-block__left">
# <h2 class="b-tit">
# <span class="b-tit__date"></span>
# </h2>
# <ul class="b-list-inline b-clearfix job-list-item__company">
# <li class="b-list-inline__ad-icon"></li>
# <li></li>
# </ul>
# <ul class="b-list-inline b-clearfix job-list-intro b-content job-list-item__summary">
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
# <p class="job-list-item__info b-content"></p>
# <p class="job-list-item__info b-content"></p>
# <div class="job-list-tag b-content">
# <span class="b-tag--default"></span>
# </div>
# </div>
# <div class="b-block__right b-pos-relative">
# <div class="rule-out b-hide">
# <button class="b-btn b-btn--icon b-drowdown rule-out__btn js-exclude">icon</button>
# <ul class="b-drowdown__menu b-drowdown__right">
# <li>不想看到這個公司</li>
# <li>不想看到這個產業</li>
# </ul>
# </div>
# <button class="b-btn b-btn--active" disabled=""></button>
# <button class="b-btn b-btn--default" disabled=""></button>
# <button class="b-btn b-btn--link" disabled=""></button>
# </div>
# </div>
# <div class="b-block--top-bord job-list-item b-block--load b-clearfix js-loading-refresh b-hide">
# <div class="b-block__left">
# <h2 class="b-tit">
# <span class="b-tit__date"></span>
# </h2>
# <ul class="b-list-inline b-clearfix job-list-item__company">
# <li class="b-list-inline__ad-icon"></li>
# <li></li>
# </ul>
# <ul class="b-list-inline b-clearfix job-list-intro b-content job-list-item__summary">
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
# <p class="job-list-item__info b-content"></p>
# <p class="job-list-item__info b-content"></p>
# <div class="job-list-tag b-content">
# <span class="b-tag--default"></span>
# </div>
# </div>
# <div class="b-block__right b-pos-relative">
# <div class="rule-out b-hide">
# <button class="b-btn b-btn--icon b-drowdown rule-out__btn js-exclude">icon</button>
# <ul class="b-drowdown__menu b-drowdown__right">
# <li>不想看到這個公司</li>
# <li>不想看到這個產業</li>
# </ul>
# </div>
# <button class="b-btn b-btn--active" disabled=""></button>
# <button class="b-btn b-btn--default" disabled=""></button>
# <button class="b-btn b-btn--link" disabled=""></button>
# </div>
# </div>
# <div class="b-block--top-bord job-list-item b-block--load b-clearfix js-loading-refresh b-hide">
# <div class="b-block__left">
# <h2 class="b-tit">
# <span class="b-tit__date"></span>
# </h2>
# <ul class="b-list-inline b-clearfix job-list-item__company">
# <li class="b-list-inline__ad-icon"></li>
# <li></li>
# </ul>
# <ul class="b-list-inline b-clearfix job-list-intro b-content job-list-item__summary">
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
# <p class="job-list-item__info b-content"></p>
# <p class="job-list-item__info b-content"></p>
# <div class="job-list-tag">
# <span class="b-tag--default"></span>
# </div>
# </div>
# <div class="b-block__right b-pos-relative">
# <div class="rule-out b-hide">
# <button class="b-btn b-btn--icon b-drowdown rule-out__btn js-exclude">icon</button>
# <ul class="b-drowdown__menu b-drowdown__right">
# <li>不想看到這個公司</li>
# <li>不想看到這個產業</li>
# </ul>
# </div>
# <button class="b-btn b-btn--active" disabled=""></button>
# <button class="b-btn b-btn--default" disabled=""></button>
# <button class="b-btn b-btn--link" disabled=""></button>
# </div>
# </div>
# <div id="js-job-content">
# <article class="b-block--top-bord job-list-item b-clearfix js-job-item js-job-item--focus b-block--ad" data-cust-name="Kloudless, A Netskope Company_科迪股份有限公司" data-cust-no="130000000096911" data-indcat="" data-indcat-desc="" data-is-apply="0" data-is-save="0" data-job-name="Sr. Manager, Datapath Engineering" data-job-no="12492407" data-job-ro="1" data-jobsource="hotjob_chr" data-qa-id="jobSeachResult">
# <div class="b-block__left">
# <h2 class="b-tit">
# <span class="b-tit__date"> <svg class="b-icon--gray b-icon--w18">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-focus"></use>
# </svg> </span>
# <a class="js-job-link" data-qa-id="jobSeachResultTitle" href="//www.104.com.tw/job/7fr7b?jobsource=hotjob_chr" target="_blank">Sr. Manager, Datapath Engineering</a>
# </h2>
# <ul class="b-list-inline b-clearfix">
# <li class="b-list-inline__ad-icon"> </li>
# <li>
# <a href="//www.104.com.tw/company/1a2x6bk233?jobsource=hotjob_chr" target="_blank" title="公司名：Kloudless, A Netskope Company_科迪股份有限公司
# 公司住址：台北市信義區信義路四段460號14樓">Kloudless, A Netskope Company_科迪股份有限公司
#                     </a>
# </li> </ul>
# <ul class="b-list-inline b-clearfix job-list-intro b-content">
# <li>台北市信義區</li>
# <div class="b-divide"></div>
# <li>10年以上</li> <div class="b-divide"></div>
# <li>大學</li> </ul> <p class="job-list-item__info b-clearfix b-content">Netskope recently acquired a startup called Kloudless (科迪股份有限公司), which is now Netskope’s subsidiary in Taiwan. The Kloudless team has been integrated into Netskope’s product and engineering teams, and its technology powers SaaS protection products in the Netskope Security Cloud.
#
# Job Duties
#
# The Netskope Cloud Datapath team architects and designs one of the most scalable, high-performance cloud data planes in the world, processing 10+ Gbps of traffic, performing deep inspection using state-of-the-art techniques like AI/ML to detect activities and apply advanced policies like DLP, Threat, and UEBA protection, all at line rate.
#
# In this role, you will set up the NG-SWG Engineering team in Taiwan and contribute to building our in-line CASB and SWG products, both of which have been recognized by Gartner as market leaders in their Magic Quadrants.
#
# [Responsibilities]
#
# - Collaborate with product managers and architects and lead building key in-line CASB and SWG features.
# - Maintain and increase Product resiliency and sustainability.
# - Manage high-profile talents, coach, mentor, and encourage growth and career progress of team members.
# - Enable teams to build well-designed quality software.
# - Establish best practices and code hygiene in software development
#
# [Qualifications/Requirements]
#
# - B.S./M.S. degree from a recognized and accredited university/college
# - Minimum 12 + years of relevant work experience with 3 +Years in a managerial role
# - Experience in network and web security technologies (firewalls, web security, IDP / IPS, DNS-based security, etc.)
# - Proponent of TDD is a big plus, knowledge of various unit testing frameworks
# - Programming mastery in C/C++ and Python
# - Strong understanding of computer architecture – multi-threading, CPU scheduling, memory management
# - Ability to suggest coding best practices and bring in effective code review feedback.
# - Function well in a fast-paced and rapidly-changing environment
# - Strong verbal and written communication skills. Communicate in an open, transparent and consistent manner with team and co-workers.
# - Determined and ever-ready to roll up sleeves to respond to the needs of customers proactively and promptly.
# - Proven history of building a high-performance team</p> <div class="job-list-tag b-content"> <span class="b-tag--default">年薪1,200,000元以上</span> <span class="b-tag--default">外商公司</span> <span class="b-tag--default">員工40人</span> <span class="b-tag--default">距捷運台北101/世貿站400公尺</span> </div>
# </div>
# <div class="b-block__right b-pos-relative"> <button class="b-btn js-save gtm-list-save b-btn--default">
# <svg class="icon-star b-icon--gray b-icon--w18 gtm-list-save">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-star"></use>
# </svg>
# <span class="gtm-list-save">儲存</span>
# </button> <button class="b-btn js-apply b-btn--default gtm-applybtn-hotjob" data-qa-id="jobSeachApplyButton" ​=""> <svg class="icon-apply b-icon--gray b-icon--w18">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-apply"></use>
# </svg>
# <span>應徵</span> </button> <a class="b-link--gray gtm-list-apply" href="//www.104.com.tw/jobs/apply/analysis/7fr7b?channel=104rpt&amp;jobsource=hotjob_chr" target="_blank">0~5人應徵</a> </div>
# </article>
# <article class="b-block--top-bord job-list-item b-clearfix js-job-item js-job-item--focus b-block--ad" data-cust-name="台灣美光(台灣美光晶圓科技股份有限公司/台灣美光記憶體股份有限公司/美商美光亞太科技股份有限公司台灣分公司)" data-cust-no="80353271000" data-indcat="" data-indcat-desc="" data-is-apply="0" data-is-save="0" data-job-name="ENGINEER, PACKAGE ASSEMBLY PROCESS INTEGRATION" data-job-no="10003810" data-job-ro="1" data-jobsource="hotjob_chr" data-qa-id="jobSeachResult">
# <div class="b-block__left">
# <h2 class="b-tit">
# <span class="b-tit__date"> <svg class="b-icon--gray b-icon--w18">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-focus"></use>
# </svg> </span>
# <a class="js-job-link" data-qa-id="jobSeachResultTitle" href="//www.104.com.tw/job/5yezm?jobsource=hotjob_chr" target="_blank">ENGINEER, PACKAGE ASSEMBLY PROCESS INTEGRATION</a>
# </h2>
# <ul class="b-list-inline b-clearfix">
# <li class="b-list-inline__ad-icon"> </li>
# <li>
# <a href="//www.104.com.tw/company/10ww9gpk?jobsource=hotjob_chr" target="_blank" title="公司名：台灣美光(台灣美光晶圓科技股份有限公司/台灣美光記憶體股份有限公司/美商美光亞太科技股份有限公司台灣分公司)
# 公司住址：台中市后里區三豐路4段369號">台灣美光(台灣美光晶圓科技股份有限公司/台灣美光記憶體股份有限公司/美商美光亞太科技股份有限公司台灣分公司)
#                     </a>
# </li> </ul>
# <ul class="b-list-inline b-clearfix job-list-intro b-content">
# <li>台中市后里區</li>
# <div class="b-divide"></div>
# <li>3年以上</li> <div class="b-divide"></div>
# <li>大學</li> </ul> <p class="job-list-item__info b-clearfix b-content">Specific Responsibilities:
#
# Advanced package technology (chip stacking, 2.5D or 3D) research and development
# PWF(MEOL) and Assembly Process Integration for 3DI/TSV HBM(High Bandwidth Memory)
# Familiar with JMP data analysis and DOE matrix design and analysis
# Material characterization experience
# Process problem identification and solving
# Work effectively to produce cross sections cooperation
#
# According to the "Employment Service Act", positions with salary lower than NTD$40,000, please refer to the salary information in the job description. Positions with salary over than NTD$40,000 will be subject to be discussed during interview.</p> <div class="job-list-tag b-content"> <span class="b-tag--default">待遇面議</span> <span class="b-tag--default">上市上櫃</span> <span class="b-tag--default">外商公司</span> <span class="b-tag--default">員工9000人</span> </div>
# </div>
# <div class="b-block__right b-pos-relative"> <button class="b-btn js-save gtm-list-save b-btn--default">
# <svg class="icon-star b-icon--gray b-icon--w18 gtm-list-save">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-star"></use>
# </svg>
# <span class="gtm-list-save">儲存</span>
# </button> <button class="b-btn js-apply b-btn--default gtm-applybtn-hotjob" data-qa-id="jobSeachApplyButton" ​=""> <svg class="icon-apply b-icon--gray b-icon--w18">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-apply"></use>
# </svg>
# <span>應徵</span> </button> <a class="b-link--gray gtm-list-apply" href="//www.104.com.tw/jobs/apply/analysis/5yezm?channel=104rpt&amp;jobsource=hotjob_chr" target="_blank">11~30人應徵</a> </div>
# </article>
# <article class="b-block--top-bord job-list-item b-clearfix js-job-item js-job-item--focus b-block--ad" data-cust-name="台灣美光(台灣美光晶圓科技股份有限公司/台灣美光記憶體股份有限公司/美商美光亞太科技股份有限公司台灣分公司)" data-cust-no="80353271000" data-indcat="" data-indcat-desc="" data-is-apply="0" data-is-save="0" data-job-name="SR. ENGINEER, MATERIAL CHARACTERIZATION" data-job-no="12306661" data-job-ro="1" data-jobsource="hotjob_chr" data-qa-id="jobSeachResult">
# <div class="b-block__left">
# <h2 class="b-tit">
# <span class="b-tit__date"> <svg class="b-icon--gray b-icon--w18">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-focus"></use>
# </svg> </span>
# <a class="js-job-link" data-qa-id="jobSeachResultTitle" href="//www.104.com.tw/job/7brvp?jobsource=hotjob_chr" target="_blank">SR. ENGINEER, MATERIAL CHARACTERIZATION</a>
# </h2>
# <ul class="b-list-inline b-clearfix">
# <li class="b-list-inline__ad-icon"> </li>
# <li>
# <a href="//www.104.com.tw/company/10ww9gpk?jobsource=hotjob_chr" target="_blank" title="公司名：台灣美光(台灣美光晶圓科技股份有限公司/台灣美光記憶體股份有限公司/美商美光亞太科技股份有限公司台灣分公司)
# 公司住址：台中市后里區三豐路4段369號">台灣美光(台灣美光晶圓科技股份有限公司/台灣美光記憶體股份有限公司/美商美光亞太科技股份有限公司台灣分公司)
#                     </a>
# </li> </ul>
# <ul class="b-list-inline b-clearfix job-list-intro b-content">
# <li>台中市后里區</li>
# <div class="b-divide"></div>
# <li>1年以上</li> <div class="b-divide"></div>
# <li>博士</li> </ul> <p class="job-list-item__info b-clearfix b-content">As a Sr. Material Characterization Engineer-Advanced Packaging Technology Development you will be responsible for global coordination of mechanical characterization and testing for advanced packaging development efforts. You will develop and document test methods as needed to characterize materials, processes, and semiconductor packages to globally support Materials Engineering, Simulation Engineering, Process Development Engineering, Process Engineering, QRA Engineering, and Supplier Quality Engineering teams. You will review and summarize data to provide recommendations or material roadmap to these teams. You will develop and enable new mechanical characterization methods for advanced materials and package technology concepts that are capable of enabling global site requirements. You will provide recommendations for test structure and test vehicle design. Close collaboration with multiple engineering teams in Close collaboration with multiple engineering teams in development, process integration, design, assembly, product engineering, and quality is required.</p> <div class="job-list-tag b-content"> <span class="b-tag--default">待遇面議</span> <span class="b-tag--default">上市上櫃</span> <span class="b-tag--default">外商公司</span> <span class="b-tag--default">員工9000人</span> </div>
# </div>
# <div class="b-block__right b-pos-relative"> <button class="b-btn js-save gtm-list-save b-btn--default">
# <svg class="icon-star b-icon--gray b-icon--w18 gtm-list-save">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-star"></use>
# </svg>
# <span class="gtm-list-save">儲存</span>
# </button> <button class="b-btn js-apply b-btn--default gtm-applybtn-hotjob" data-qa-id="jobSeachApplyButton" ​=""> <svg class="icon-apply b-icon--gray b-icon--w18">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-apply"></use>
# </svg>
# <span>應徵</span> </button> <a class="b-link--gray gtm-list-apply" href="//www.104.com.tw/jobs/apply/analysis/7brvp?channel=104rpt&amp;jobsource=hotjob_chr" target="_blank">11~30人應徵</a> </div>
# </article>
# <article class="b-block--top-bord job-list-item b-clearfix js-job-item js-job-item--focus b-block--ad" data-cust-name="沛思坦網路股份有限公司" data-cust-no="130000000167016" data-indcat="" data-indcat-desc="" data-is-apply="0" data-is-save="0" data-job-name="[Taipei]Legal Evidence Consultant" data-job-no="12517455" data-job-ro="1" data-jobsource="hotjob_chr" data-qa-id="jobSeachResult">
# <div class="b-block__left">
# <h2 class="b-tit">
# <span class="b-tit__date"> <svg class="b-icon--gray b-icon--w18">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-focus"></use>
# </svg> </span>
# <a class="js-job-link" data-qa-id="jobSeachResultTitle" href="//www.104.com.tw/job/7gaj3?jobsource=hotjob_chr" target="_blank">[Taipei]Legal Evidence Consultant</a>
# </h2>
# <ul class="b-list-inline b-clearfix">
# <li class="b-list-inline__ad-icon"> </li>
# <li>
# <a href="//www.104.com.tw/company/1a2x6blk6g?jobsource=hotjob_chr" target="_blank" title="公司名：沛思坦網路股份有限公司
# 公司住址：台北市內湖區堤頂大道二段181號2樓">沛思坦網路股份有限公司
#                     </a>
# </li> </ul>
# <ul class="b-list-inline b-clearfix job-list-intro b-content">
# <li>台北市內湖區</li>
# <div class="b-divide"></div>
# <li>經歷不拘</li> <div class="b-divide"></div>
# <li>大學</li> </ul> <p class="job-list-item__info b-clearfix b-content">Job brief:
#
# At Pacston Technology, we integrate technology and customer service skills to assist our clients in managing their academic portfolio.
#
# We are looking for a legal evidence consultant who will be responsible for managing day to day legal affairs and evaluating confidential data for the distribution of project related deadlines. Consultants should be able to determine satisfactory applications of legal research documents and problem-solve in a timely manner. A high-performing consultant can become a manager in 3-6 months.
#
# We have offices in Taipei, Hsinchu and Taichung city so our consultants can choose one that suits best for their working location.
#
# Objectives:
#
#  - Coordinate interactions between client and counsel to determine collection and storage of sensitive data
#  - Review legal documents and conduct legal research
#
# Responsibilities:
#
#  - Review and evaluate documents provided by the clients
#  - Manage day to day legal affairs
#  - Communicate with clients in a timely manner
#  - Distribute confidential and sensitive materials
#
# Skills and qualifications:
#
#  - Attention to detail
#  - Strong written communication skills
#  - Ability to multitask and manage project deadlines
#  - Legal knowledge or related working experience is  not required
# </p> <div class="job-list-tag b-content"> <span class="b-tag--default">待遇面議</span> <span class="b-tag--default">員工200人</span> </div>
# </div>
# <div class="b-block__right b-pos-relative"> <button class="b-btn js-save gtm-list-save b-btn--default">
# <svg class="icon-star b-icon--gray b-icon--w18 gtm-list-save">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-star"></use>
# </svg>
# <span class="gtm-list-save">儲存</span>
# </button> <button class="b-btn js-apply b-btn--default gtm-applybtn-hotjob" data-qa-id="jobSeachApplyButton" ​=""> <svg class="icon-apply b-icon--gray b-icon--w18">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-apply"></use>
# </svg>
# <span>應徵</span> </button> <a class="b-link--gray gtm-list-apply" href="//www.104.com.tw/jobs/apply/analysis/7gaj3?channel=104rpt&amp;jobsource=hotjob_chr" target="_blank">0~5人應徵</a> </div>
# </article>
# ...
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-star"></use>
# </svg>
# <span class="gtm-list-save">儲存</span>
# </button> <button class="b-btn js-apply b-btn--default" data-qa-id="jobSeachApplyButton" ​=""> <svg class="icon-apply b-icon--gray b-icon--w18">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-apply"></use>
# </svg>
# <span>應徵</span> </button> <a class="b-link--gray gtm-list-apply" href="//www.104.com.tw/jobs/apply/analysis/7bdqr?channel=104rpt&amp;jobsource=apply_analyze" target="_blank">0~5人應徵</a> </div>
# </article>
# <article class="b-block--top-bord job-list-item b-clearfix js-job-item" data-cust-name="IBM_台灣國際商業機器股份有限公司" data-cust-no="11917900000" data-indcat="1001001001" data-indcat-desc="電腦系統整合服務業" data-is-apply="0" data-is-save="0" data-job-name="Big Data Engineer" data-job-no="12361772" data-job-ro="1" data-jobsource="jolist_c_relevance" data-qa-id="jobSeachResult">
# <div class="b-block__left">
# <h2 class="b-tit">
# <span class="b-tit__date">11/26                </span>
# <a class="js-job-link" data-qa-id="jobSeachResultTitle" href="//www.104.com.tw/job/7cyek?jobsource=jolist_c_relevance" target="_blank">Big <em class="b-txt--highlight">Data</em> Engineer</a>
# </h2>
# <ul class="b-list-inline b-clearfix">
# <li class="b-list-inline__ad-icon"> <svg class="b-icon--gray b-icon--w16">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-company"></use>
# </svg> </li>
# <li>
# <a href="//www.104.com.tw/company/5h3lyhs?jobsource=jolist_c_relevance" target="_blank" title="公司名：IBM_台灣國際商業機器股份有限公司
# 公司住址：台北市南港區三重路19-11號E棟9F">IBM_台灣國際商業機器股份有限公司
#                     </a>
# </li> <div class="b-divide"></div>
# <li>電腦系統整合服務業</li> </ul>
# <ul class="b-list-inline b-clearfix job-list-intro b-content">
# <li>台北市南港區</li>
# <div class="b-divide"></div>
# <li>5年以上</li> <div class="b-divide"></div>
# <li>大學</li> </ul> <p class="job-list-item__info b-clearfix b-content">We are looking for talents with skills and interests as Big <em class="b-txt--highlight">Data</em> Engineer who will join us to develop enterprise scale</p> <div class="job-list-tag b-content"> <span class="b-tag--default">待遇面議</span> <span class="b-tag--default">外商公司</span> <span class="b-tag--default">距捷運南港軟體園區站310公尺</span> </div>
# </div>
# <div class="b-block__right b-pos-relative"> <div class="rule-out">
# <button class="b-btn b-btn--icon b-drowdown rule-out__btn b-clear-margin js-exclude">
# <svg class="b-icon--weak-gray b-icon--w12">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-arrow-down"></use>
# </svg>
# </button>
# <ul class="b-drowdown__menu b-drowdown__right b-hide">
# <li class="js-exclude-company gtm-exclude-company">不想看到這個公司</li>
# <li class="js-exclude-industry gtm-exclude-industry">不想看到這個產業</li>
# </ul>
# </div> <button class="b-btn js-save gtm-list-save b-btn--default">
# <svg class="icon-star b-icon--gray b-icon--w18 gtm-list-save">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-star"></use>
# </svg>
# <span class="gtm-list-save">儲存</span>
# </button> <button class="b-btn js-apply b-btn--default" data-qa-id="jobSeachApplyButton" ​=""> <svg class="icon-apply b-icon--gray b-icon--w18">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-apply"></use>
# </svg>
# <span>應徵</span> </button> <a class="b-link--gray gtm-list-apply" href="//www.104.com.tw/jobs/apply/analysis/7cyek?channel=104rpt&amp;jobsource=apply_analyze" target="_blank">0~5人應徵</a> </div>
# </article>
# <article class="b-block--top-bord job-list-item b-clearfix js-job-item" data-cust-name="順立智慧股份有限公司" data-cust-no="130000000046441" data-indcat="1001001006" data-indcat-desc="其它軟體及網路相關業" data-is-apply="0" data-is-save="0" data-job-name="Data Engineer_Intern" data-job-no="11932286" data-job-ro="2" data-jobsource="jolist_c_relevance" data-qa-id="jobSeachResult">
# <div class="b-block__left">
# <h2 class="b-tit">
# <span class="b-tit__date">11/29                </span>
# <a class="js-job-link" data-qa-id="jobSeachResultTitle" href="//www.104.com.tw/job/73r0e?jobsource=jolist_c_relevance" target="_blank"><em class="b-txt--highlight">Data</em> Engineer_Intern</a>
# </h2>
# <ul class="b-list-inline b-clearfix">
# <li class="b-list-inline__ad-icon"> </li>
# <li>
# <a href="//www.104.com.tw/company/1a2x6biz55?jobsource=jolist_c_relevance" target="_blank" title="公司名：順立智慧股份有限公司
# 公司住址：台北市內湖區內湖路一段360巷8號7樓">順立智慧股份有限公司
#                     </a>
# </li> <div class="b-divide"></div>
# <li>其它軟體及網路相關業</li> </ul>
# <ul class="b-list-inline b-clearfix job-list-intro b-content">
# <li>台北市內湖區</li>
# <div class="b-divide"></div>
# <li>經歷不拘</li> <div class="b-divide"></div>
# <li>大學</li> </ul> <p class="job-list-item__info b-clearfix b-content">&lt;職務說明&gt;
# 1. Develop tools for <em class="b-txt--highlight">data</em> collection, cleansing, processing, storage, and analytics
# 2. Develop <em class="b-txt--highlight">data</em> visualization to</p> <div class="job-list-tag b-content"> <span class="b-tag--default">時薪200元</span> <span class="b-tag--default">員工120人</span> <span class="b-tag--default">距捷運西湖站340公尺</span> </div>
# </div>
# <div class="b-block__right b-pos-relative"> <div class="rule-out">
# <button class="b-btn b-btn--icon b-drowdown rule-out__btn b-clear-margin js-exclude">
# <svg class="b-icon--weak-gray b-icon--w12">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-arrow-down"></use>
# </svg>
# </button>
# <ul class="b-drowdown__menu b-drowdown__right b-hide">
# <li class="js-exclude-company gtm-exclude-company">不想看到這個公司</li>
# <li class="js-exclude-industry gtm-exclude-industry">不想看到這個產業</li>
# </ul>
# </div> <button class="b-btn js-save gtm-list-save b-btn--default">
# <svg class="icon-star b-icon--gray b-icon--w18 gtm-list-save">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-star"></use>
# </svg>
# <span class="gtm-list-save">儲存</span>
# </button> <button class="b-btn js-apply b-btn--default" data-qa-id="jobSeachApplyButton" ​=""> <svg class="icon-apply b-icon--gray b-icon--w18">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-apply"></use>
# </svg>
# <span>應徵</span> </button> <a class="b-link--gray gtm-list-apply" href="//www.104.com.tw/jobs/apply/analysis/73r0e?channel=104rpt&amp;jobsource=apply_analyze" target="_blank">0~5人應徵</a> </div>
# </article>
# <article class="b-block--top-bord job-list-item b-clearfix js-job-item" data-cust-name="hyve solutions_海峰電腦股份有限公司" data-cust-no="130000000042926" data-indcat="1001001001" data-indcat-desc="電腦系統整合服務業" data-is-apply="0" data-is-save="0" data-job-name="Software Data Engineer" data-job-no="7687108" data-job-ro="1" data-jobsource="jolist_c_relevance" data-qa-id="jobSeachResult">
# <div class="b-block__left">
# <h2 class="b-tit">
# <span class="b-tit__date">11/30                </span>
# <a class="js-job-link" data-qa-id="jobSeachResultTitle" href="//www.104.com.tw/job/4kres?jobsource=jolist_c_relevance" target="_blank">Software <em class="b-txt--highlight">Data</em> Engineer</a>
# </h2>
# <ul class="b-list-inline b-clearfix">
# <li class="b-list-inline__ad-icon"> <svg class="b-icon--gray b-icon--w16">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-company"></use>
# </svg> </li>
# <li>
# <a href="//www.104.com.tw/company/1a2x6biwfi?jobsource=jolist_c_relevance" target="_blank" title="公司名：hyve solutions_海峰電腦股份有限公司
# 公司住址：桃園市龜山區文化二路202號4樓">hyve solutions_海峰電腦股份有限公司
#                     </a>
# </li> <div class="b-divide"></div>
# <li>電腦系統整合服務業</li> </ul>
# <ul class="b-list-inline b-clearfix job-list-intro b-content">
# <li>桃園市龜山區</li>
# <div class="b-divide"></div>
# <li>2年以上</li> <div class="b-divide"></div>
# <li>大學</li> </ul> <p class="job-list-item__info b-clearfix b-content">built <em class="b-txt--highlight">data</em> center servers and solutions. Help us design server platforms at scale.
# We are looking for talented software <em class="b-txt--highlight">data</em></p> <div class="job-list-tag b-content"> <span class="b-tag--default">待遇面議</span> <span class="b-tag--default">外商公司</span> <span class="b-tag--default">員工1003人</span> </div>
# </div>
# <div class="b-block__right b-pos-relative"> <div class="rule-out">
# <button class="b-btn b-btn--icon b-drowdown rule-out__btn b-clear-margin js-exclude">
# <svg class="b-icon--weak-gray b-icon--w12">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-arrow-down"></use>
# </svg>
# </button>
# <ul class="b-drowdown__menu b-drowdown__right b-hide">
# <li class="js-exclude-company gtm-exclude-company">不想看到這個公司</li>
# <li class="js-exclude-industry gtm-exclude-industry">不想看到這個產業</li>
# </ul>
# </div> <button class="b-btn js-save gtm-list-save b-btn--default">
# <svg class="icon-star b-icon--gray b-icon--w18 gtm-list-save">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-star"></use>
# </svg>
# <span class="gtm-list-save">儲存</span>
# </button> <button class="b-btn js-apply b-btn--default" data-qa-id="jobSeachApplyButton" ​=""> <svg class="icon-apply b-icon--gray b-icon--w18">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-apply"></use>
# </svg>
# <span>應徵</span> </button> <a class="b-link--gray gtm-list-apply" href="//www.104.com.tw/jobs/apply/analysis/4kres?channel=104rpt&amp;jobsource=apply_analyze" target="_blank">0~5人應徵</a> </div>
# </article> </div>
# <div class="b-block b-txt--center" id="js-loading-next-page">
# <icon class="fa fa-spinner fa-pulse"></icon>
#                     載入第<span>1</span>頁
#                 </div>
# </div>
# </div>
# <aside class="l-content--2col--sub">
# <section>
# <article class="ad-article adima-section js-ad-article js-fetching">
# <div class="loading"><div class="sidebar-loading">
# <div class="loading-main">
# <div class="loading-circle">
# </div>
# </div>
# </div>
# </div>
# <div class="content">
# <h3>強力放送</h3>
# <div board="ad-article"></div>
# </div>
# </article>
# <article class="js-ad-img js-fetching">
# <div class="loading"><div class="sidebar-loading">
# <div class="loading-main">
# <div class="loading-circle">
# </div>
# </div>
# </div>
# </div>
# <div class="content">
# <div board="ad-img"></div>
# </div>
# </article>
# </section><div id="sidebar-tool"></div>
# </aside>
# </div>
# </main>
# <div id="divorg"></div><div id="app-footer"></div><div class="b-popup-overlay b-hide"></div><div class="b-popup b-popup--m mate-box b-hide" id="saveCondition">
# <h2 class="b-popup__title">檢視或訂閱條件</h2>
# <div class="b-popup__content"> <div class="b-txt--center" id="not-login-mate">請登入my104會員中心</div> <div class="b-txt--center login-mate" id="login-mate">
# <p class="subscription-text">將本次搜尋條件儲存為配對工作，即可收到最新的工作通知</p>
# <p class="subscription-condition">
#                 您的條件：
#                 <span class="js-filter-desc"></span>
# </p>
# <div class="subscription-form">
# <div>
# <p class="b-txt--center js-notice-text subscription-notice"></p>
# <input class="js-under-condition is-large" type="text" value=""/>
# <div class="js-over-condition is-large b-inline-block">
# <select class="cus-select"></select>
# </div>
# <a class="gtm-subscription-edit" href="//pda.104.com.tw/work/mate/" target="_blank">
#                         編輯配對條件
#                     </a>
# <div class="b-error-msg js-msg"></div>
# </div>
# <div class="check-mail"> <label class="js-mate-emailbox subscription-mail">
# <input class="b-checkbox" type="checkbox"/>配對信同步寄至：
#                         <span class="js-mate-mail"></span>
# </label>
# <a class="js-edit-mail" href="javascript:void(0)" target="_blank">
#                         修改接收信箱
#                     </a>
# </div>
# </div>
# </div>
# </div>
# <div class="b-popup__footer">
# <button class="b-btn b-btn--normal is-large js-popup-close gtm-subscription-cancel">
#             取消
#         </button>
# <button class="b-btn b-btn--primary is-large js-on-ok gtm-subscription-send">
#             確認
#         </button>
# </div>
# <div class="b-popup__msg b-hide js-msg">
# <p>請選擇要取代的配對條件。</p>
# </div>
# <div class="b-popup__close js-popup-close">
# <svg class="icon-clear b-icon--weak-gray b-icon--w16">
# <use xlink:href="//www.104.com.tw/jobs/search/static/img/sprite.svg#icon-clear"></use>
# </svg>
# </div>
# </div><div class="b-popup b-hide notice js-notice">
# <h2 class="b-popup__title b-txt--left">有新工作立即通知？</h2>
# <div class="b-popup__content">
#         將本次搜尋條件儲存成工作配對，即可在「My104、手機App、E-mail」收到最新的工作通知。
#     </div>
# <div class="b-popup__footer b-txt--right b-clear-margin">
# <button class="b-btn b-btn--text" id="noticeOnClose">我知道了</button>
# <button class="b-btn b-btn--normal gtm-notice-subscription" id="noticeOnOk">訂閱</button>
# </div>
# </div><div class="b-block--loading" id="js-action-overlay">
# <div class="b-center">
# <div class="loader-inner ball-spin-fade-loader"></div>
# <div>資料處理中…</div>
# </div>
# </div><form id="js-action-form" method="post" name="actionForm" target="_blank"></form><script src="//static.104.com.tw/104main/libs/mit/jquery/3.3.1/jquery.min.js"></script>
# <script src="//static.104.com.tw/104main/libs/mit/vue/2.6.12/vue.min.js"></script>
# <script src="//www.104.com.tw/jobs/search/static/js/vendor.js?v=210217"></script><script>
#     var defPublicPath = "//www.104.com.tw",
#         defCasePath   = "//case.104.com.tw",
#         defTutorPath  = "//tutor.104.com.tw",
#         defLearnPath  = "//learn.104.com.tw";
#     var defAssetsPath = "//www.104.com.tw/jobs/search/static";
#     var initFilter ={"query":{"ro":0,"jobcat":"","isnew":"","kwop":7,"keyword":"data","expansionType":"area,spec,com,job,wf,wktm","excludeKeyword":"","area":"","indcat":"","expcate":"","edu":"","order":12,"asc":0,"zone":"","dep":"","dis_role":"","lang":"","sr":"","sctp":"","scmin":"","scmax":"","scstrict":"","scneg":"","excludeJobKeyword":"","excludeCompanyKeyword":"","excludeCompanyByCustno":"","excludeIndustryCat":"","s9":"","s5":"","wktm":"","startby":"","rostatus":"","page":"","wf":"","jobexp":"","wt":"","mode":"s","jobsource":"2018indexpoc","utm_source":"","utm_medium":"","utm_campaign":"","c":"","custNo":"","jobNo":"","dist":"","lat":"","lon":"","indArea":"","newZone":"","searchTempExclude":"","manage":"","showLatLon":"","showDutyTime":"","langFlag":0,"remoteWork":"","mrt":""},"filterDesc":{"jobcat":[],"indcat":[],"area":[],"dep":[],"mrt":[],"excludeIndustryCat":[],"excludeCompanyByCustno":[],"recommendIndcat":[{"no":"1001000000","des":"\u96fb\u5b50\u8cc7\u8a0a\uff0f\u8edf\u9ad4\uff0f\u534a\u5c0e\u9ad4\u76f8\u95dc\u696d"},{"no":"1002000000","des":"\u4e00\u822c\u88fd\u9020\u696d"},{"no":"1003000000","des":"\u6279\u767c\uff0f\u96f6\u552e\uff0f\u50b3\u76f4\u92b7\u696d"},{"no":"1001001000","des":"\u8edf\u9ad4\u53ca\u7db2\u8def\u76f8\u95dc\u696d"},{"no":"1007000000","des":"\u65c5\u904a\uff0f\u4f11\u9592\uff0f\u904b\u52d5\u696d"}],"indArea":[],"recommendMrt":[{"no":"99001001016","des":"\u897f\u6e56\u7ad9"},{"no":"99001005018","des":"\u5e02\u653f\u5e9c\u7ad9"},{"no":"99001005019","des":"\u6c38\u6625\u7ad9"},{"no":"99001003017","des":"\u5357\u4eac\u5fa9\u8208\u7ad9"},{"no":"99001004008","des":"\u677e\u6c5f\u5357\u4eac\u7ad9"},{"no":"99001003019","des":"\u5357\u4eac\u4e09\u6c11\u7ad9"}]},"queryDesc":{"ro":"\u5168\u90e8\u5de5\u4f5c","keyword":"data"},"count":["5779","5477","126","26","150","0","0"],"pageNo":1,"totalPage":150,"totalCount":5779,"firstCustNo":"12861019000"};
#     var staticPath = "//static.104.com.tw";
#     $('.loader-inner').loaders();
#     var adsmartDiamondData = {};
#     var adsmartBoardId ={"keywordCompany":333,"keyword":339};
#     var cards ={"showStudentCard":false,"showHigherCard":false,"showResumeClinicCard":false};
# </script><script src="https://msc.adsmart.104.com.tw/js/channel.js?v=210825"></script><script src="//www.104.com.tw/public/function01/menu/js/e104menu2011.js?v=210217"></script><script src="//static.104.com.tw/104i/js/api/log/e104.log.latest.js?v=210217"></script><script src="//static.104.com.tw/bubble/js/mainjs.js?v=210217"></script><script src="//www.104.com.tw/jobs/search/static/js/common.min.js?v=210217"></script>
# <script src="//www.104.com.tw/jobs/search/static/js/joblist.bundle.min.js?v=210217"></script><script src="//cdn.104.com.tw/common/v1.0/assets/js/common-footer.js"></script><script src="//cdn.104.com.tw/common/v1.0/assets/js/common-sidebar-tool.js"></script>
# </body>
# </html>

# %%
url = "https://www.104.com.tw/job/7bbe1?jobsource=jolist_b_relevance"

res = requests.get(url, headers=headers)
soup = BeautifulSoup(res.text, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="zh-Hant-TW">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width,initial-scale=1.0" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/> <title>大數據工程師｜安智聯科技有限公司｜桃園市桃園區－104 人力銀行</title> <meta content="【工作內容】桃園市桃園區 - 【工作說明】
# 1. 搭建分散式系統
# 2. 維運分散式系統及其上的job
# 3. 與PM溝通產品策略方向及開發進度規劃
# 4. 能配合短期出差
#
# 【專業需求】
# 兩年以上的分散式系統建立與維護經驗
# 熟悉had…。薪資：月薪55,000元以上。職務類別：軟體設計工程師、資料庫管理人員、Internet程式設計師。休假制度：週休二日。可上班日：不限。工作性質：全職。主動應徵、找工作，請上 104 人力銀行投遞履歷。" name="description"/>
# <link href="https://www.104.com.tw/job/7bbe1" rel="canonical"/>
# <link href="https://m.104.com.tw/job/7bbe1" media="handheld" rel="alternate"/>
# <link href="https://m.104.com.tw/job/7bbe1" media="only screen and (max-width: 640px)" rel="alternate"/>
# <link href="https://m.104.com.tw/amp/job/7bbe1" rel="amphtml"/>
# <link href="android-app://com.m104/m104/job?j=5f61436e396d4a6b49333d643d3f37608393b436c35373f683d433b1e1e1e1e1a745615d2a77j02&amp;jobNo=7bbe1" rel="alternate"/>
# <link href="ios-app://437817158/m104/job?j=5f61436e396d4a6b49333d643d3f37608393b436c35373f683d433b1e1e1e1e1a745615d2a77j02&amp;jobNo=7bbe1" rel="alternate"/>
# <meta content="index,follow,noarchive" name="robots"/> <meta content="大數據工程師｜安智聯科技有限公司｜桃園市桃園區－104 人力銀行" property="og:title"/>
# <meta content="【工作內容】桃園市桃園區 - 【工作說明】
# 1. 搭建分散式系統
# 2. 維運分散式系統及其上的job
# 3. 與PM溝通產品策略方向及開發進度規劃
# 4. 能配合短期出差
#
# 【專業需求】
# 兩年以上的分散式系統建立與維護經驗
# 熟悉had…。薪資：月薪55,000元以上。職務類別：軟體設計工程師、資料庫管理人員、Internet程式設計師。休假制度：週休二日。可上班日：不限。工作性質：全職。主動應徵、找工作，請上 104 人力銀行投遞履歷。" property="og:description"/>
# <meta content="https://www.104.com.tw/job/7bbe1" property="og:url"/>
# <meta content="article" property="og:type"/>
# <meta content="https://static.104.com.tw/logo/104logo_997x523_fbogD2.png" property="og:image"/>
# <meta content="找頭鹿找工作｜104 人力銀行" property="og:image:alt"/>
# <meta content="516245975144411" property="fb:app_id"/>
# <meta content="104 人力銀行" property="og:site_name"/> <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://static.104.com.tw" rel="dns-prefetch"/>
# <link href="//cdn.104.com.tw" rel="dns-prefetch"/>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#             new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#             j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#             'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#         })(window,document,'script','dataLayer','GTM-P379T3');</script>
# <!-- End Google Tag Manager -->
# <script src="https://static.104.com.tw/104i/js/api/log/e104.log.latest.js?v=20190424"></script> <script src="https://static.104.com.tw/104main/libs/mit/jquery/3.3.1/jquery.min.js"></script>
# <script src="https://static.104.com.tw/104main/libs/mit/jquery-migrate/3.0.1/jquery-migrate.min.js" type="text/javascript"></script>
# <script src="https://static.104.com.tw/104main/libs/mit/jquery-migrate/1.4.1/jquery-migrate.min.js" type="text/javascript"></script>
# <script src="https://static.104.com.tw/bubble/js/mainjs.js?by=jbbar&amp;v=20200323" type="text/javascript"></script> <link href="//cdn.104.com.tw/designer-icons/1.1.12/style.css" rel="stylesheet" type="text/css"> <link href="//cdn.104.com.tw/cindex/assets/css/chunk-vendors.6215e04d.css" rel="stylesheet"/>
# <link href="//cdn.104.com.tw/cindex/assets/css/cindex-job.14e1fe66.css" rel="stylesheet"/>
# </link></head>
# <body>
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-P379T3" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) --> <div id="globalbar">
# <div id="bar_m104">
# <div id="global_bk"></div>
# </div>
# </div> <noscript>
# <strong>We're sorry but vue-start doesn't work properly without JavaScript enabled. Please enable it to continue.</strong>
# </noscript>
# <div id="app"></div>
# <script defer="" src="https://static.104.com.tw/104main/libs/mit/vue/2.6.12/vue.min.js"></script>
# <script defer="" src="https://msc.adsmart.104.com.tw/js/channel.js?v=210825"></script>
# <script defer="" src="//cdn.104.com.tw/cindex/assets/js/core-js.edfc25abd9b3f3af4e95.js"></script>
# <script defer="" src="//cdn.104.com.tw/cindex/assets/js/vue.857f299b2d2843024b9e.js"></script>
# <script defer="" src="//cdn.104.com.tw/cindex/assets/js/popper.js.bd447390f014ce81a0fe.js"></script>
# <script defer="" src="//cdn.104.com.tw/cindex/assets/js/v-tooltip.3f3583a15f7d35b1ff12.js"></script>
# <script defer="" src="//cdn.104.com.tw/cindex/assets/js/chunk-vendors.d5bf0fd5d112f300693a.js"></script>
# <script defer="" src="//cdn.104.com.tw/cindex/assets/js/cindex-job.33b0626e10a1a79b7ce1.js"></script>
# <!-- Start Alexa Certify Javascript -->
# <script type="text/javascript">
#         _atrk_opts = { atrk_acct:"lRlHh1awVK00wf", domain:"104.com.tw",dynamic: true};
#         (function() { var as = document.createElement('script'); as.type = 'text/javascript'; as.async = true; as.src = "https://d31qbv1cthcecs.cloudfront.net/atrk.js"; var s = document.getElementsByTagName('script')[0];s.parentNode.insertBefore(as, s); })();
#     </script>
# <noscript><img alt="" height="1" src="https://d5nxst8fruw4z.cloudfront.net/atrk.gif?account=lRlHh1awVK00wf" style="display:none" width="1"/></noscript>
# <!-- End Alexa Certify Javascript -->
# </body>
# </html>

# %%
headers = {
    "Accept": "application/json, text/plain, */*",
    "Accept-Encoding": "gzip, deflate, br",
    "Accept-Language": "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6",
    "Connection": "keep-alive",
    "Host": "www.104.com.tw",
    "Referer": f"https://www.104.com.tw/job/{a}?jobsource=hotjob_chr",
    "sec-ch-ua": '" Not A;Brand";v="99", "Chromium";v="96", "Google Chrome";v="96"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": "Windows",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin",
    "User-Agent": ua.random
}

# %%
a=soup.select('link')[0]['href']
a="7bbe1"

url = f'https://www.104.com.tw/job/ajax/content/{a}'
res = rs.get(url, headers=headers)
res.text
# Out:
# '{"data":{"corpImageRight":{"corpImageRight":{"imageUrl":"","link":""}},"header":{"corpImageTop":{"imageUrl":"","link":""},"jobName":"\\u5927\\u6578\\u64da\\u5de5\\u7a0b\\u5e2b","appearDate":"2021\\/11\\/22","custName":"\\u5b89\\u667a\\u806f\\u79d1\\u6280\\u6709\\u9650\\u516c\\u53f8","custUrl":"https:\\/\\/www.104.com.tw\\/company\\/1a2x6bkzzz","applyDate":"","analysisType":1,"analysisUrl":"\\/\\/www.104.com.tw\\/jobs\\/apply\\/analysis\\/7bbe1","isSaved":false,"isApplied":false},"contact":{"hrName":"\\u694a\\u5c0f\\u59d0","email":"","visit":"","phone":"","other":"","reply":"\\u5408\\u9069\\u8005\\u5c07\\u65bc3\\u500b\\u5de5\\u4f5c\\u5929\\u5167\\u4e3b\\u52d5\\u806f\\u7e6b\\uff0c\\u4e0d\\u5408\\u9069\\u8005\\u5c07\\u4e0d\\u53e6\\u884c\\u901a\\u77e5","suggestExam":false},"environmentPic":{"environmentPic":[{"thumbnailLink":"https:\\/\\/static.104.com.tw\\/b_profile\\/cust_picture\\/0863\\/130000000140863\\/env\\/s_890328564413054729.jpg?v=20210824100437","link":"https:\\/\\/static.104.com.tw\\/b_profile\\/cust_picture\\/0863\\/130000000140863\\/env\\/l_890328564413054729.jpg?v=20210824100437","description":""},{"thumbnailLink":"https:\\/\\/static.104.com.tw\\/b_profile\\/cust_picture\\/0863\\/130000000140863\\/env\\/s_962627717424937644.jpg?v=20210824100437","link":"https:\\/\\/static.104.com.tw\\/b_profile\\/cust_picture\\/0863\\/130000000140863\\/env\\/l_962627717424937644.jpg?v=20210824100437","description":""},{"thumbnailLink":"https:\\/\\/static.104.com.tw\\/b_profile\\/cust_picture\\/0863\\/130000000140863\\/env\\/s_962627717424937645.jpg?v=20210824100437","link":"https:\\/\\/static.104.com.tw\\/b_profile\\/cust_picture\\/0863\\/130000000140863\\/env\\/l_962627717424937645.jpg?v=20210824100437","description":""}],"corpImageBottom":{"imageUrl":"","link":""}},"condition":{"acceptRole":{"role":[{"code":1,"description":"\\u4e0a\\u73ed\\u65cf"}],"disRole":{"needHandicapCompendium":false,"disability":[]}},"workExp":"2\\u5e74\\u4ee5\\u4e0a","edu":"\\u5927\\u5b78\\u3001\\u78a9\\u58eb","major":["\\u8cc7\\u8a0a\\u5de5\\u7a0b\\u76f8\\u95dc","\\u5176\\u4ed6\\u6578\\u5b78\\u53ca\\u96fb\\u7b97\\u6a5f\\u79d1\\u5b78\\u76f8\\u95dc"],"language":[{"language":"\\u82f1\\u6587","ability":"\\u807d \\/\\u4e2d\\u7b49\\u3001\\u8aaa \\/\\u7565\\u61c2\\u3001\\u8b80 \\/\\u4e2d\\u7b49\\u3001\\u5beb \\/\\u7565\\u61c2"}],"localLanguage":[],"specialty":[{"code":"12001001029","description":"UNIX"},{"code":"12001003025","description":"Java"},{"code":"12001003045","description":"Python"},{"code":"12001004031","description":"MS SQL"},{"code":"12001004035","description":"Oracle"},{"code":"12001004039","description":"PostgreSQL"}],"skill":[{"code":"11009002004","description":"\\u7cfb\\u7d71\\u67b6\\u69cb\\u898f\\u5283"},{"code":"11009002008","description":"\\u8edf\\u9ad4\\u5de5\\u7a0b\\u7cfb\\u7d71\\u958b\\u767c"},{"code":"11009005001","description":"\\u8edf\\u9ad4\\u7a0b\\u5f0f\\u8a2d\\u8a08"},{"code":"11009006001","description":"\\u8cc7\\u6599\\u5eab\\u7cfb\\u7d71\\u7ba1\\u7406\\u7dad\\u8b77"},{"code":"11009006002","description":"\\u8cc7\\u6599\\u5eab\\u7a0b\\u5f0f\\u8a2d\\u8a08"}],"certificate":[],"driverLicense":[],"other":""},"welfare":{"tag":["\\u6176\\u751f\\u6703","\\u54e1\\u5de5\\u7d05\\u5229","\\u5e74\\u7d42\\u734e\\u91d1","\\u4e09\\u7bc0\\u734e\\u91d1\\/\\u79ae\\u54c1"],"welfare":"\\u5b89\\u667a\\u806f\\u70ba\\u4e00\\u5bb6\\u8d70\\u5728\\u667a\\u80fd\\u88fd\\u9020\\u524d\\u7aef\\u7684\\u61c9\\u7528\\u8edf\\u9ad4\\u8207\\u7cfb\\u7d71\\u6574\\u5408\\u670d\\u52d9\\u516c\\u53f8\\uff0c\\u63d0\\u4f9b\\u5b8c\\u6574\\u6559\\u80b2\\u8a13\\u7df4\\uff0c\\u671f\\u8a31\\u54e1\\u5de5\\u8207\\u516c\\u53f8\\u4e00\\u540c\\u8ffd\\u6c42\\u9032\\u6b65\\uff0c\\u5728\\u9019\\u88e1\\u627e\\u5230\\u5c6c\\u65bc\\u81ea\\u5df1\\u7684\\u672a\\u4f86\\u8207\\u767c\\u5c55\\u7a7a\\u9593\\u3002\\u540c\\u6642\\uff0c\\u6211\\u5011\\u4e5f\\u95dc\\u5fc3\\u60a8\\u8207\\u5bb6\\u4eba\\u7684\\u5065\\u5eb7\\uff0c\\u9664\\u4e86\\u7b26\\u5408\\u52de\\u52d5\\u57fa\\u6e96\\u6cd5\\u898f\\u5b9a\\ ...

# %%
res.text.encode("utf-8").decode("unicode_escape")
# Out:
# C:\Users\TIBEME~1\AppData\Local\Temp/ipykernel_7544/802710587.py:1: DeprecationWarning: invalid escape sequence '\/'
#   res.text.encode("utf-8").decode("unicode_escape")
# '{"data":{"corpImageRight":{"corpImageRight":{"imageUrl":"","link":""}},"header":{"corpImageTop":{"imageUrl":"","link":""},"jobName":"大數據工程師","appearDate":"2021\\/11\\/22","custName":"安智聯科技有限公司","custUrl":"https:\\/\\/www.104.com.tw\\/company\\/1a2x6bkzzz","applyDate":"","analysisType":1,"analysisUrl":"\\/\\/www.104.com.tw\\/jobs\\/apply\\/analysis\\/7bbe1","isSaved":false,"isApplied":false},"contact":{"hrName":"楊小姐","email":"","visit":"","phone":"","other":"","reply":"合適者將於3個工作天內主動聯繫，不合適者將不另行通知","suggestExam":false},"environmentPic":{"environmentPic":[{"thumbnailLink":"https:\\/\\/static.104.com.tw\\/b_profile\\/cust_picture\\/0863\\/130000000140863\\/env\\/s_890328564413054729.jpg?v=20210824100437","link":"https:\\/\\/static.104.com.tw\\/b_profile\\/cust_picture\\/0863\\/130000000140863\\/env\\/l_890328564413054729.jpg?v=20210824100437","description":""},{"thumbnailLink":"https:\\/\\/static.104.com.tw\\/b_profile\\/cust_picture\\/0863\\/130000000140863\\/env\\/s_962627717424937644.jpg?v=20210824100437","link":"https:\\/\\/static.104.com.tw\\/b_profile\\/cust_picture\\/0863\\/130000000140863\\/env\\/l_962627717424937644.jpg?v=20210824100437","description":""},{"thumbnailLink":"https:\\/\\/static.104.com.tw\\/b_profile\\/cust_picture\\/0863\\/130000000140863\\/env\\/s_962627717424937645.jpg?v=20210824100437","link":"https:\\/\\/static.104.com.tw\\/b_profile\\/cust_picture\\/0863\\/130000000140863\\/env\\/l_962627717424937645.jpg?v=20210824100437","description":""}],"corpImageBottom":{"imageUrl":"","link":""}},"condition":{"acceptRole":{"role":[{"code":1,"description":"上班族"}],"disRole":{"needHandicapCompendium":false,"disability":[]}},"workExp":"2年以上","edu":"大學、碩士","major":["資訊工程相關","其他數學及電算機科學相關"],"language":[{"language":"英文","ability":"聽 \\/中等、說 \\/略懂、讀 \\/中等、寫 \\/略懂"}],"localLanguage":[],"specialty":[{"code":"12001001029","description":"UNIX"},{"code":"12001003025","description":"Java"},{"code":"12001003045","description":"Python"},{"code":"12001004031","description":"MS SQL"},{"code":"12001004035","description":"Oracle"},{"code":"12001004039","description":"PostgreSQL"}],"skill":[{"code":"11009002004","description":"系統架構規劃"},{"code":"11009002008","description":"軟體工程系統開發"},{"code":"11009005001","description":"軟體程式設計"},{"code":"11009006001","description":"資料庫系統管理維護"},{"code":"11009006002","description":"資料庫程式設計"}],"certificate":[],"driverLicense":[],"other":""},"welfare":{"tag":["慶生會","員工紅利","年終獎金","三節獎金\\/禮品"],"welfare":"安智聯為一家走在智能製造前端的應用軟體與系統整合服務公司，提供完整教育訓練，期許員工與公司一同追求進步，在這裡找到屬於自己的未來與發展空間。同時，我們也關心您與家人的健康，除了符合勞動基準法規定之勞\\/健保、年假和周休二日外，我們還提供以下福利措施：\n\n※\t分紅\\/配股\n1.\t員工紅利；2.員工認股 \n※ 獎金\\/禮金類\n1.年終獎金；2.績效獎金；3.生日禮金； 4.結婚禮金； 5.生育津貼； 6.交通津貼補助； 7. 員工聚餐\n※ 請假\\/休假制度 \n1.週休二日；2.特休\\/年假；3.家庭照顧假；4.女性同仁生理假；5. 女性同仁產假；6. 男性同仁陪產假；7.同仁育嬰假\n※ 職涯發展\n1.完整的教育訓練；2.參與國內外研討會；3.多元、國際發展管道\n\n希望具有前瞻性與挑戰心的您加入安智聯，與公司一同進步共同成長，開發你無盡的潛能與光明前景。\n","legalTag":["週休二日"]},"jobDetail":{"jobDescription":"【工作說明】\n1. 搭建分散式系統\n2. 維運分散式系統及其上的job\n3. 與PM溝通產品策略方向及開發進度規劃\n4. 能配合短期出差\n\n【專業需求】\n兩年以上的分散式系統建立與維護經驗\n熟悉hadoop\n熟悉Git 版本管控\n能和多人協作專案\n有使用Linux 或UNIX的作業系統經驗\n熟悉Docker\n\n【\x08加分條件】\n1. 有JavaScript Framework Vue.js , VUE CLI 等前端框架開發經驗\n2. ETL \n3. HTML, CSS, Jquery\n4. Python\n5. 曾使用過雲端服務 (AWS, GCP, Azure)","jobCategory":[{"code":"2007001004","description":"軟體設計工程師"},{"code":"2007002002","description":"資料庫管理人員"},{"code":"2007001006","description":"Internet程式設計師"}],"salary":"月薪55,000元以上","salaryMin":55000,"salaryMax":9999999,"salaryType":50,"jobType":1,"workType":[],"addressNo":"6001005007","addressRegion":"桃園市桃園區","addressDetail":"成功路三段1號 (虎頭山創新園區)","industryArea":"","longitude":"121.3237702","latitude":"24.9979294","manageResp":"不需負擔管理責任","businessTrip":"需出差，一年累積時間約三個月以下","workPeriod":"日班","vacationPolicy":"週休二日","startWorkingDay":"不限","hireType":0,"delegatedRecruit":"","needEmp":"1人","landmark":"","remoteWork":null},"switch":"on","custLogo":"https:\\/\\/static.104.com.tw\\/b_profile\\/cust_picture\\/0863\\/130000000140863\\/logo.jpg?v=20210824100437","postalCode" ...

# %%
res.text
# Out:
# '<!DOCTYPE html>\n<html lang="zh-Hant-TW">\n<head>\n    <meta charset="utf-8" />\n    <meta http-equiv="X-UA-Compatible" content="IE=edge" />\n    <meta name="viewport" content="width=device-width,initial-scale=1.0" />\n    <meta name="format-detection" content="telephone=no">        <title>大數據工程師｜安智聯科技有限公司｜桃園市桃園區－104 人力銀行</title>        <meta name="description" content="【工作內容】桃園市桃園區 - 【工作說明】\n1. 搭建分散式系統\n2. 維運分散式系統及其上的job\n3. 與PM溝通產品策略方向及開發進度規劃\n4. 能配合短期出差\n\n【專業需求】\n兩年以上的分散式系統建立與維護經驗\n熟悉had…。薪資：月薪55,000元以上。職務類別：軟體設計工程師、資料庫管理人員、Internet程式設計師。休假制度：週休二日。可上班日：不限。工作性質：全職。主動應徵、找工作，請上 104 人力銀行投遞履歷。">\n        <link rel="canonical" href="https://www.104.com.tw/job/7bbe1" />\n        <link rel="alternate" media="handheld" href="https://m.104.com.tw/job/7bbe1">\n        <link rel="alternate" media="only screen and (max-width: 640px)" href="https://m.104.com.tw/job/7bbe1">\n        <link rel="amphtml" href="https://m.104.com.tw/amp/job/7bbe1">\n        <link rel="alternate" href="android-app://com.m104/m104/job?j=5f61436e396d4a6b49333d643d3f37608393b436c35373f683d433b1e1e1e1e1a745615d2a77j02&amp;jobNo=7bbe1">\n        <link rel="alternate" href="ios-app://437817158/m104/job?j=5f61436e396d4a6b49333d643d3f37608393b436c35373f683d433b1e1e1e1e1a745615d2a77j02&amp;jobNo=7bbe1">\n        <meta name="robots" content="index,follow,noarchive">        <meta property="og:title" content="大數據工程師｜安智聯科技有限公司｜桃園市桃園區－104 人力銀行">\n        <meta property="og:description" content="【工作內容】桃園市桃園區 - 【工作說明】\n1. 搭建分散式系統\n2. 維運分散式系統及其上的job\n3. 與PM溝通產品策略方向及開發進度規劃\n4. 能配合短期出差\n\n【專業需求】\n兩年以上的分散式系統建立與維護經驗\n熟悉had…。薪資：月薪55,000元以上。職務類別：軟體設計工程師、資料庫管理人員、Internet程式設計師。休假制度：週休二日。可上班日：不限。工作性質：全職。主動應徵、找工作，請上 104 人力銀行投遞履歷。">\n        <meta property="og:url" content="https://www.104.com.tw/job/7bbe1">\n        <meta property="og:type" content="article">\n        <meta property="og:image" content="https://static.104.com.tw/logo/104logo_997x523_fbogD2.png">\n        <meta property="og:image:alt" content="找頭鹿找工作｜104 人力銀行">\n        <meta property="fb:app_id" content="516245975144411">\n        <meta property="og:site_name" content="104 人力銀行">    <meta http-equiv="x-dns-prefetch-control" content="on">\n    <link rel="dns-prefetch" href="https://static.104.com.tw">\n    <link rel="dns-prefetch" href="//cdn.104.com.tw">\n    <!-- Google Tag Manager -->\n    <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\n            new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\n            j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n            \'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n        })(window,document,\'script\',\'dataLayer\',\'GTM-P379T3\');</script>\n    <!-- End Google Tag Manager -->\n    <script src="https://static.104.com.tw/104i/js/api/log/e104.log.latest.js?v=20190424"></script>    <script src="https://static.104.com.tw/104main/libs/mit/jquery/3.3.1/jquery.min.js"></script>\n    <script\n            type="text/javascript"\n            src="https://static.104.com.tw/104main/libs/mit/jquery-migrate/3.0.1/jquery-migrate.min.js"\n    ></script>\n    <script\n            type="text/javascript"\n            src="https://static.104.com.tw/104main/libs/mit/jquery-migrate/1.4.1/jquery-migrate.min.js"\n    ></script>\n    <script\n            type="text/javascript"\n            src="https://static.104.com.tw/bubble/js/mainjs.js?by=jbbar&v=20200323"\n    ></script>    <link rel="stylesheet" type="text/css" href="//cdn.104.com.tw/designer-icons/1.1.12/style.css"/>    <link href="//cdn.104.com.tw/cindex/assets/css/chunk-vendors.6215e04d.css" rel=stylesheet>\n    <link href="//cdn.104.com.tw/cindex/assets/css/cindex-job.14e1fe66.css" rel=stylesheet>\n</head>\n<body>\n    <!-- Google Tag Manager (noscript) -->\n    <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-P379T3"\n                      height="0" width="0" style="display:none;visibility:hid ...

# %%
import requests
from fake_useragent import UserAgent
from bs4 import BeautifulSoup
import pandas as pd
import traceback
import logging.config
from datetime import datetime
import time
import sys


class OneOFour:
    def __init__(self):
        self.__rs = requests.session()
        self.__urlHome = "https://www.104.com.tw/"
        self.__urlSearch = "https://www.104.com.tw/jobs/search/"
        self.__userAgent = ""

        logging.config.fileConfig(f'logging.conf')
        self.__logger = logging.getLogger('timeRotateLogger')

    def search(self, kwd: str, maxPages: int = 3):
        try:
            self.__getCookies(kwd)
        except Exception as e:
            return self.__errLog(e)

        pageDatas = []
        for i in range(maxPages):
            print(f'\r{kwd}, page:{i+1}', end='')
            try:
                pageContent = self.__loadPage(kwd, page=i+1)
            except Exception as e:
                return self.__errLog(e)

            try:
                pageData = self.__sourceExtract(pageContent)
                pageDatas.extend(pageData)
            except Exception as e:
                return self.__errLog(e)

            time.sleep(3)

        df = pd.DataFrame(pageDatas, columns=(
            "更新日期", "職缺連結", "職缺名稱", "公司名稱", "公司連結",
            "所屬產業", "所在區域", "工作經歷", "學歷要求", "職缺描述"))

        fileTime = datetime.now().strftime("%Y-%m-%d %H-%M-%S")
        df.to_excel(
            f'104_{kwd}_first {maxPages} pages_{fileTime}.xlsx', index=False)
        return "Done"

    def __getCookies(self, kwd: str) -> None:
        '''get cookies'''
        self.__userAgent = UserAgent().random
        headers = {
            "user-agent": self.__userAgent
        }

        self.__rs.get(self.__urlHome, headers=headers)

    def __loadPage(self, kwd: str, page: int) -> bytes:
        data = {
            "ro": 0,
            "kwop": 11,
            "keyword": kwd,
            "expansionType": "job",
            "order": 14,
            "asc": 0,
            "page": page,
            "mode": "s",
            "jobsource": "2018indexpoc",
            "langFlag": 0
        }

        referer = self.__urlSearch + "?"
        for k, v in data.items():
            referer += f"{k}={v}&"

        headers = {
            "Accept": "application/json, text/javascript, */*; q=0.01",
            "Accept-Encoding": "gzip, deflate, br",
            "Accept-Language": "zh-TW,zh;q=0.9,en;q=0.8,en-GB;q=0.7,en-US;q=0.6",
            "Connection": "keep-alive",
            "Host": "www.104.com.tw",
            "Referer": referer[:-1].encode('utf-8'),
            "sec-ch-ua": '"Microsoft Edge";v="95", "Chromium";v="95", ";Not A Brand";v="99"',
            "sec-ch-ua-mobile": "?0",
            "sec-ch-ua-platform": "Windows",
            "Sec-Fetch-Dest": "empty",
            "Sec-Fetch-Mode": "cors",
            "Sec-Fetch-Site": "same-origin",
            "User-Agent": self.__userAgent,
        }

        temp = self.__rs.get(referer, headers=headers)
        # print(self.__rs.cookies)
        return temp.content

    def __sourceExtract(self, pageContent: bytes) -> list:
        soup = BeautifulSoup(pageContent, 'html5lib')
        article = soup.find_all(
            "article", {"class": "b-block--top-bord job-list-item b-clearfix js-job-item"})

        pageData = []
        for i in range(len(article)):
            temp = article[i]
            # 更新日期、職缺連結、職缺名稱
            dateAndUrl = temp.select(".b-tit")
            update = dateAndUrl[0].select(".b-tit__date")[0].text
            joblink = dateAndUrl[0].find('a')['href'][2:]
            job = dateAndUrl[0].find('a').text

            # 公司名稱、公司連結、所屬產業
            temp = article[i].find_all('ul')
            company = temp[0].find_all('li')[1].text.replace(
                ' ', '').replace('\n', '')
            companyLink = temp[0].find_all('a')[0]['href'][2:]
            industry = temp[0].find_all(
                'li')[-1].text.replace(' ', '').replace('\n', '')

            # 所在區域、工作經歷、學歷要求
            area = temp[1].find_all('li')[0].text.replace(
                ' ', '').replace('\n', '')
            experience = temp[1].find_all('li')[1].text.replace(
                ' ', '').replace('\n', '')
            Education = temp[1].find_all('li')[2].text.replace(
                ' ', '').replace('\n', '')

            # 職缺描述
            temp = article[i].find_all('p')[0]
            jobDescribe = temp.text.replace('\n', '')

            # 更新日期、職缺連結、職缺名稱、公司名稱、公司連結、所屬產業、所在區域、工作經歷、學歷要求、職缺描述
            pageData.append([update, joblink, job, company, companyLink, industry,
                             area, experience, Education, jobDescribe])

        return pageData

    def __errLog(self, e):
        self.__logger.error(f'{str(e)}\n{traceback.format_exc()}')
        return f'{e}\nDetail: err.log'


if __name__ == '__main__':
    try:
        kwd, maxPages = sys.argv[1:]
    except Exception as e:
        print(e)
    else:
        if maxPages.isdigit():
            res = OneOFour().search(kwd, maxPages=int(maxPages))
            print(f'\n{res}')
        else:
            print("""在命令列使用python 104.py arg1(關鍵字) arg2(前n頁)
                    ex. python 104.py 軟體 3
                    代表到104爬取關鍵字為軟體的前3頁
                """)
